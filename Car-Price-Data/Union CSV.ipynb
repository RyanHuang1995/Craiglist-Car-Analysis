# %%
import pandas as pd
import sqlite3

# %%
models = ["accord","altima","camry","civic","corolla","prius"]

# %%
csv_file_path = [f"{model}_data.csv" for model in models]
csv_file_path
# Out:
# ['accord_data.csv',
#  'altima_data.csv',
#  'camry_data.csv',
#  'civic_data.csv',
#  'corolla_data.csv',
#  'prius_data.csv']

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in csv_file_path], sort=True)

# %%
combined_csv.to_csv("combined_csv.csv")
combined_df = pd.read_csv("combined_csv.csv")
conn = sqlite3.connect("Craiglist.db")
combined_df.to_sql("Craiglist_Car",conn,if_exists = "replace")
# Out:
# C:\Users\tomhd\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py:2130: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)

# %%
pd.read_sql_query("select * from `Craiglist_Car`;", conn)
# Out:
#       index  Unnamed: 0   Condition     Cylinders Drive     Fuel  \
# 0         0           0        good   4 cylinders   fwd      gas
# 1         1           1   excellent   4 cylinders  None      gas
# 2         2           2        good   4 cylinders   fwd      gas
# 3         3           3    like new   4 cylinders   fwd      gas
# 4         4           4        good   4 cylinders   fwd      gas
# 5         5           5   excellent   4 cylinders  None      gas
# 6         6           6    like new   6 cylinders   fwd      gas
# 7         7           7   excellent   4 cylinders   rwd      gas
# 8         8           8    like new   4 cylinders  None      gas
# 9         9           9    like new   4 cylinders  None      gas
# 10       10          10    like new   4 cylinders  None      gas
# 11       11          11    like new   4 cylinders  None      gas
# 12       12          12   excellent   4 cylinders   fwd      gas
# ...
