# %%
 # Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd

# %%
csv_file_path = ("../Car price data/altima_data.csv")

# %%
# Using Splinter Scraping data
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
# URL of page to be scraped
url = 'https://losangeles.craigslist.org/search/cto?min_price=2000&auto_make_model=Altima&min_auto_year=2008&max_auto_year=2018&min_auto_miles=0&max_auto_miles=1000000&condition=10&condition=20&condition=30&condition=40'

# %%
# Scrape the data based on post info
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html,"html.parser")
next_page = soup.find("a",class_ = "button next")["href"]

titles = []
prices = []
links = []
car_data = []

while next_page:
    print(" - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - - ")
    html = browser.html
    soup = BeautifulSoup(html,"html.parser")
    results = soup.find_all('li', class_="result-row")
    
    
    
    
    for result in results:
    # Error handling
        try:
            # Identify and return title of listing
            title = result.find('a', class_="result-title").text
            # Identify and return price of listing
            price = result.a.span.text
            # Identify and return link to listing
            link = result.a['href']

            # Print results only if title, price, and link are available
            if (title and price and link):
                titles.append(title)
                prices.append(price)
                links.append(link)
                
                post_link = result.a["href"]
                response2 = requests.get(post_link)
                soup2 = BeautifulSoup(response2.text,"html.parser")
                attributes = soup2.find_all("p",class_="attrgroup")
                attribute_list = attributes[1].find_all("span")
                yearlist = [str(num) for num in list(range(1900, 2020))]
                tag = attributes[0].find_
                attr_dic = {}
                for attr in attribute_list:
                    try:
                        key,value = attr.text.split(":")
                        attr_dic[key] = value
                    except ValueError:
                        pass
    
                car_data.append(attr_dic)
                
                
        except AttributeError as e:
            print(e)
    try:
        browser.click_link_by_partial_text('next')
        next_page = soup.find("a",class_ = "button next")["href"]
    except:
        print("- - - - - - - - - This is the last page we can find!!!- - - - - -")
        next_page = False
# Out:
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# - - - - - - - - - This is the last page we can find!!!- - - - - -

# %%
# Store info as dataframe
info_df = pd.DataFrame({
    "Info" : titles,
    "Price" : prices,
    "links" : links
})

# %%
# Show full dataframe
pd.set_option('display.max_colwidth', -1)
# Merge two dataframe
car_df = pd.DataFrame(car_data)
car_df["Title"] = info_df["Info"]
car_df["Price"] = info_df["Price"]
car_df["links"] = info_df["links"]
car_df["Make"] = "Nissan"
car_df["Model"] = "Altima"
car_df.tail(50)
# Out:
#                     VIN   condition     cylinders drive     fuel odometer  \
# 103  NaN                  excellent   4 cylinders   fwd   gas      103000
# 104  NaN                  excellent   4 cylinders  NaN    gas      91300
# 105  NaN                  good        4 cylinders   fwd   gas      134000
# 106  NaN                  good        4 cylinders   rwd   gas      75054
# 107  NaN                  good        4 cylinders   fwd   gas      123000
# 108  NaN                  new         4 cylinders   fwd   gas      20000
# 109  NaN                  like new    4 cylinders   fwd   gas      99552
# 110  NaN                  good       NaN           NaN    hybrid   200000
# 111  NaN                  excellent   4 cylinders   fwd   gas      16000
# 112  NaN                  excellent   4 cylinders   fwd   gas      67000
# 113  NaN                  excellent   4 cylinders   fwd   diesel   185000
# 114  NaN                  excellent   4 cylinders   fwd   gas      118000
# 115  NaN                  good       NaN           NaN    gas      120754
# 116  NaN                  good        4 cylinders   rwd   gas      87
# 117  NaN                  good        4 cylinders   rwd   gas      87
# 118   1N4AL2AP3BN455469   excellent   4 cylinders  NaN    gas      115000
# 119  NaN                  like new    4 cylinders   fwd   gas      28000
# 120  NaN                  good        4 cylinders  NaN    gas      115000
# 121  NaN                  good        4 cylinders   rwd   gas      87
# 122  NaN                  good        4 cylinders  NaN    gas      93000
# 123  NaN                  like new    4 cylinders   fwd   gas      35500
# 124  NaN                  excellent   4 cylinders  NaN    gas      93
# 125  NaN                  excellent   4 cylinders   fwd   gas      43000
# 126   1N4AL3AP2HC227456   like new    4 cylinders   rwd   gas      16700
# 127  NaN                  good        4 cylinders  NaN    gas      160000
# 128   1N4AL2APXCC141296   excellent   4 cylinders   fwd   gas      97121
# 129  NaN                  excellent   4 cylinders   fwd   gas      97121
# 130  NaN                  excellent   4 cylinders  NaN    gas      65472
# 131  NaN                  good        4 cylinders   fwd   gas      75000
# 132  NaN                  good        4 cylinders   fwd   gas      152000
# 133  NaN                  excellent   4 cylinders   fwd   hybrid   89000
# 134  NaN                  good        4 cylinders  NaN    gas      106000
# 135  NaN                  excellent   4 cylinders   fwd   gas      11865
# 136  NaN                  good        4 cylinders   fwd   gas      139000
# 137  NaN                  good        4 cylinders   fwd   gas      56000
# 138   1N4BL21E89N438180   good        6 cylinders   fwd   gas      184000
# 139  NaN                  like new    4 cylinders  NaN    gas      84
# 140  NaN                  good        4 cylinders   fwd   gas      70500
# 141  NaN                  like new    4 cylinders   fwd   gas      14999
# 142  NaN                  good        6 cylinders  NaN    gas      153000
# 143  NaN                  good        4 cylinders   fwd   gas      111
# 144  NaN                  good        4 cylinders  NaN    gas      74528
# 145  NaN                  good       NaN           NaN    gas      108000
# 146  NaN                  good       NaN           NaN    gas      85000
# 147  NaN                  good        4 cylinders  NaN    gas      80000
# 148  NaN                  like new    4 cylinders   fwd   gas      48400
# 149  NaN                  like new    4 cylinders  NaN    gas      65000
# 150  NaN                  excellent   4 cylinders  NaN    gas      50000
# 151  NaN                  good        4 cylinders   fwd   gas      144000
# 152  NaN                  excellent   4 cylinders   fwd   gas      89923
#
#     paint color        size title status transmission     type  \
# 103   blue        full-size   salvage      automatic    sedan
# 104   black      NaN          clean        automatic   NaN
# 105   white       full-size   clean        automatic    pickup
# 106   grey        mid-size    clean        automatic    sedan
# 107   red         full-size   salvage      automatic   NaN
# 108   black       mid-size    clean        automatic    sedan
# 109   white       mid-size    clean        automatic    sedan
# 110  NaN         NaN          clean        automatic   NaN
# 111   black       full-size   clean        automatic    sedan
# 112   white       mid-size    clean        automatic    sedan
# 113  NaN          mid-size    clean        other        coupe
# 114   black       mid-size    clean        automatic    sedan
# 115   grey       NaN          clean        automatic   NaN
# 116   black       compact     clean        automatic    sedan
# 117   black       compact     clean        automatic    sedan
# 118   black      NaN          clean        automatic    sedan
# 119   brown       full-size   salvage      automatic    sedan
# 120  NaN         NaN          clean        automatic   NaN
# 121   black       compact     clean        automatic    sedan
# 122   red         compact     clean        automatic    coupe
# 123   grey        compact     salvage      automatic    sedan
# 124   silver     NaN          lien         automatic    sedan
# 125   red         full-size   clean        automatic    sedan
# 126   blue        mid-size    salvage      automatic    sedan
# 127   red         full-size   clean        automatic    sedan
# 128   black       full-size   clean        automatic    sedan
# 129   black       full-size   clean        automatic    sedan
# 130  NaN         NaN          salvage      automatic   NaN
# 131   blue        mid-size    clean        automatic    sedan
# 132  NaN         NaN          clean        automatic   NaN
# 133   grey        full-size   salvage      automatic    sedan
# 134   silver     NaN          clean        automatic   NaN
# 135   silver     NaN          missing      automatic   NaN
# 136   white       mid-size    salvage      automatic   NaN
# 137  NaN          mid-size    salvage      automatic    sedan
# 138   silver      mid-size    clean        automatic    sedan
# 139   white      NaN          salvage      automatic   NaN
# 140   grey        mid-size    salvage      automatic    sedan
# 141   grey       NaN          clean        automatic   NaN
# 142   red         compact     clean        automatic    coupe
# 143  NaN         NaN          clean        automatic   NaN
# 144   white      NaN          clean        automatic    sedan
# 145   black      NaN          clean        automatic   NaN
# 146   silver     NaN          clean        automatic    coupe
# 147   black      NaN          clean        automatic    coupe
# 148   black       mid-size    clean        automatic    sedan
# 149   grey       NaN          clean        automatic   NaN
# 150   white       full-size   clean        automatic    sedan
# 151   black       compact     salvage      manual       coupe
# 152   silver      full-size   clean        automatic    sedan
#
#                                                                      Title  \
# 103  2010 Nissan Altima
# 104  *Great Deal* 2013 Nissan Altima SV
# 105  09 Nissan Altima
# 106  2015 Nissan Altima 2.5
# 107  2014 Nissan Altima
# 108  2016 NISSAN ALTIMA SR, BLACK/BLACK INT 4 CILINDERS
# 109  2015 Nissan Altima S,No Accidents,Well Maintained!!
# 110  Nissan Altima Hybrid 2008
# 111  2017 NISSAN ALTIMA SL 16K MILAGE LEATHER
# 112  2012 Nissan Altima * 4 Cly * Auto * * Sale, Sale, Sale * *
# 113  2010 Nissan Altima
# 114  2012 *********************** NISSAN ALTIMA
# 115  2009 Nissan Altima for Sale
# 116  2012 NISSAN ALTIMA
# 117  2012 NISSAN ALTIMA
# 118  2011 NISSAN ALTIMA 2.5 S
# 119  2015 Nissan Altima SV
# 120  2009 Nissan Altima
# 121  2012 NISSAN ALTIMA
# 122  2010 Premium Nissan Altima 2.5 S
# 123  Nissan Altima 2016
# 124  2014 Nissan Altima ~ RUNS AND LOOKS LIKE NEW !!
# 125  Red Nissan Altima for sale!!
# 126  2017 NISSAN ALTIMA SR    LOW 16,700 MILES, PADDLE SHIFTERS
# 127  2011 nissan Altima
# 128  2012 Nissan ALTIMA 2.5S Excellent Custom Wheels
# 129  2012 Nissan ALTIMA Custom wheels
","MG MOTOR","MINI","MITSUBISHI","MORGAN","NISSAN","NOBLE","OPEL","PAGANI","PERODUA","PEUGEOT","PORSCHE","PROTON","RADICAL","RAM","RENAULT","ROEWE","ROLLS","ROYCE","ROLLS-ROYCE","RUF","SALEEN","SAAB","SCION","SEAT","SKODA","SMART","SRT","SSANGYONG","SUBARU","SUPERFORMANCE","SUZUKI","TATA","TESLA","TOYOTA","TVR","ULTIMA","VAUXHALL","VENTURI","VOLKSWAGEN","VOLVO","WESTFIELD","WIESMANN","ZENVO","ALPINE","AMERICAN","ASIA","AUSTIN","HEALEY","AUSTIN-HEALEY","DAEWOO","DE TOMASO","DEVON","GUMPERT","HUMMER","INVICTA","MARCOS","MAYBACH","MORRIS","OLDSMOBILE","PLYMOUTH","PONTIAC","SATURN","SPYKER"]

yearlist = list(range(1900, 2020)) #All possible years
stryearlist = [str(item) for item in yearlist] #convert  int years in yearlist to string

mergedlist = BrandList + stryearlist #Merge list of brands and years. To be used to get model of cars

Makelist = list(set(BrandList) & set(text2list)) # Sets a new list of car make
Make = concatenate_list_data(Makelist)
print(Make)

modelist = [x for x in text2list if x not in mergedlist] # Sets a new list of car model
Model = concatenate_list_data(modelist)
print(Model)

yearlist = list(set(stryearlist) & set(text2list)) # Sets a new list of car year
Year = concatenate_list_data(yearlist)
print(Year)

# %%
def concatenate_list_data(list): #Concatenates items in list to one string
    result= ''
    for element in list:
        result += str(element + ' ')
    return result
titles = car_df["Title"]
Years = []
for title in titles:
    titlelist = title.split() #Splits words in tag string to items in list
    titlelist =[x.upper() for x in titlelist] #Converts Items in list to uppercase for comparison sake

    #Below is a list of all brands of cars
    BrandList = ["ACURA","ARASH","ALFA","ROMEO","ALFA-ROMEO","ALFA ROMEO","ARIEL","ASCARI","ASTON","MARTIN","ASTON MARTIN","AUDI","BENTLEY","BOWLER","BMW","BRIGGS","BRISTOL","BROOKE","BUGATTI","BUICK","CADILLAC","CAPARO","CATERHAM","CHERY","CHEVROLET","CHEVRON","CHRYSLER","CITROEN","CORVETTE","DAIHATSU","DATSUN","DODGE","DONKERVOORT","FERRARI","FIAT","FISKER","FORD","FPV","GINETTA","GMC","HENNESSEY","HOLDEN","HONDA","HYUNDAI","INFINITI","ISUZU","JAGUAR","JEEP","JOSS","KAMAZ","KIA","KOENIGSEGG","KTM (X-BOW)","LAMBORGHINI","LANCIA","LAND ROVER","LEXUS","LISTER","LINCOLN","LOTUS","MAHINDRA","MARUTISUZUKI","MASERATI","MASTRETTA","MAZDA","MCLAREN","MERCEDES","BENZ","MERCEDES-BENZ","MG MOTOR","MINI","MITSUBISHI","MORGAN","NISSAN","NOBLE","OPEL","PAGANI","PERODUA","PEUGEOT","PORSCHE","PROTON","RADICAL","RAM","RENAULT","ROEWE","ROLLS","ROYCE","ROLLS-ROYCE","RUF","SALEEN","SAAB","SCION","SEAT","SKODA","SMART","SRT","SSANGYONG","SUBARU","SUPERFORMANCE","SUZUKI","TATA","TESLA","TOYOTA","TVR","ULTIMA","VAUXHALL","VENTURI","VOLKSWAGEN","VOLVO","WESTFIELD","WIESMANN","ZENVO","ALPINE","AMERICAN","ASIA","AUSTIN","HEALEY","AUSTIN-HEALEY","DAEWOO","DE TOMASO","DEVON","GUMPERT","HUMMER","INVICTA","MARCOS","MAYBACH","MORRIS","OLDSMOBILE","PLYMOUTH","PONTIAC","SATURN","SPYKER"]

    yearlist = list(range(1900, 2020)) #All possible years
    stryearlist = [str(item) for item in yearlist] #convert  int years in yearlist to string

    mergedlist = BrandList + stryearlist #Merge list of brands and years. To be used to get model of cars

    Makelist = list(set(BrandList) & set(titlelist)) # Sets a new list of car make
    Make = concatenate_list_data(Makelist)
    print(Make)

    modelist = [x for x in titlelist if x not in mergedlist] # Sets a new list of car model
    Model = concatenate_list_data(modelist)
    print(Model)

    yearlist = list(set(stryearlist) & set(titlelist)) # Sets a new list of car year
    Year = concatenate_list_data(yearlist)
    Years.append(Year)
    
Years
# Out:
# NISSAN
# ALTIMA 2.5S
# NISSAN
# ALTIMA 124,000 MILES
# NISSAN
# ALTIMA 4C SEDAN
# NISSAN
# ALTIMA S SEDAN WHITE 99,000MILES
# NISSAN
# ALTIMA LOW MILEAGE CLEAN
# NISSAN
# ALTIMA LOW MILEAGE CLEAN
# NISSAN
# ALTIMA LOW MILEAGE CLEAN
# NISSAN
# ALTIMA CUSTOM WHEELS EXCELLENT
# NISSAN
# ALTIMA S WITH BACKUP CARMERA
# NISSAN
# ALTIMA VERY CLEAN I WOULD CONSIDER TAKING PAYMENTS
# NISSAN
# ALTIMA 2.5 S
# NISSAN
# ALTIMA 2.5
# NISSAN
# ALTIMA SL
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA 2.5S - CLEAN TITLE - LOW MILES
# NISSAN
# ALTIMA COUPE
# NISSAN
# ALTIMA 2.5 S NEW BODY STYLE
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA (BOSE AUDIO)
# NISSAN
# ALTIMA 80K CLEAN TITLE
# NISSAN
# ALTIMA 2.5L
# NISSAN
# ALTIMA 3.5 SE FULLY LOADED.
# NISSAN
# ALTIMA S LOW MILEAGE GREAT DEAL
# NISSAN
# ALTIMA 2.5 SL BLACK LEATHER LOW MILES
# NISSAN
# ALTIMA LOW MILEAGE CLEAN
# NISSAN
# ALTIMA 2.5S
# NISSAN
# ALTIMA SV/CLEAN TITLE/36K MILES
# NISSAN
# ALTIMA S WITH BACKUP CARMERA
# NISSAN
# ALTIMA S SEDAN WHITE 99,000MILES
# NISSAN
# ALTIMA 2.5 S 2DOORS SEDAN
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA 2.5 S
# NISSAN
# ALTIMA 2.5 S
# NISSAN
# ALTIMA SL ... ONLY 48K MILES ... EXTRA CLEAN ... MUST SEE
# NISSAN
# ALTIMA 2.5 S
# NISSAN
# ALTIMA LOW MILEAGE 59,400 MILES
# NISSAN
# ALTIMA 2.5 S
# NISSAN
# ALTIMA 2.5
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA
# NISSAN
# ALTIM
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA 2.5 S
# NISSAN
# ALTIMA SV
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA
# NISSAN
# PREMIUM ALTIMA 2.5 S
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA ~ RUNS AND LOOKS LIKE NEW !!
# NISSAN
# RED ALTIMA FOR SALE!!
# NISSAN
# ALTIMA SR LOW 16,700 MILES, PADDLE SHIFTERS
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA 2.5S EXCELLENT CUSTOM WHEELS
# NISSAN
# ALTIMA CUSTOM WHEELS
# NISSAN
# ALTIMA COUPE CIVIC TC G35
# NISSAN
# ALTIMA 2.5 S
# NISSAN
# ALTIMA 152K CLEAN
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA 11K MILES, 1 OWNER, MOVING MUST SELL
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA S 56K MILLAS
# NISSAN
# ALTIMA 3.5SE
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA 2.5 SL
# NISSAN
# ALTIMA
# NISSAN
# ALTIMA COUPE - PRICE REDUCED
# NISSAN
# ALTIMA
#
# GOOD
# NISSAN
# ALTIMA COUPE
# NISSAN
# ALTIMA COUPE FOR SALE!!
# NISSAN
# ALTIMA COUPE - BLACK 80K MILES - RUNS AMAZING *CASH ONLY*
# NISSAN
# ALTIMA 2.5 S
# NISSAN
# ALTIMA COUPE 010
# NISSAN
# ALTIMA 2.5 CLEAN TITLE
# NISSAN
# ALTIMA COUPE
# NISSAN
# 7997 ALTIMA 2.5S
# ['2008 ',
#  '2009 ',
#  '2016 ',
#  '2015 ',
#  '2014 ',
#  '2014 ',
#  '2014 ',
#  '2012 ',
#  '2014 ',
#  '2012 ',
#  '2015 ',
#  '2016 2017 ',
#  '2013 ',
#  '',
#  '2012 ',
#  '2012 ',
#  '',
#  '2008 ',
#  '2009 ',
#  '2012 ',
#  '2008 ',
#  '2009 ',
#  '2015 ',
#  '2015 ',
#  '2014 ',
#  '2012 ',
#  '2017 ',
#  '2014 ',
#  '2015 ',
#  '2008 ',
#  '2011 ',
#  '2010 ',
#  '2015 ',
#  '2008 ',
#  '2008 ',
#  '2009 ',
#  '2011 ',
#  '2016 ',
#  '2008 ',
#  '2008 ',
#  '2012 ',
#  '2013 2016 2014 2015 ',
#  '2011 ',
#  '2014 ',
#  '2014 ',
#  '2011 ',
#  '2010 ',
#  '2008 ',
#  '2012 ',
#  '2009 ',
#  '2009 ',
#  '2013 ',
#  '2008 ',
#  '2009 ',
#  '2008 ',
#  '2011 ',
#  '2014 ',
#  '2013 ',
#  '2008 ',
#  '2014 ',
#  '2011 ',
#  '2011 ',
#  '2009 ',
#  '',
#  '2010 ',
#  '2008 ',
#  '',
#  '',
#  '2014 ',
#  '2011 ',
#  '2008 ',
#  '2010 ',
#  '2010 ',
#  '2010 ',
#  '2010 ',
#  '2014 ',
#  '2010 ',
#  '2014 ',
#  '2009 ',
#  '2012 ',
#  '2008 ',
#  '2015 ',
#  '2015 ',
#  '2015 ',
#  '2010 ',
#  '2009 ',
#  '2017 ',
#  '2008 ',
#  '2008 ',
#  '2009 ',
#  '2012 ',
#  '2017 ',
#  '2012 ',
#  '2010 ',
#  '2010 ',
#  '2012 ',
#  '2009 ',
#  '',
#  '2012 ',
#  '2014 ',
#  '',
#  '2008 ',
#  '2011 ',
#  '2010 ',
#  '2013 ',
#  '',
#  '2015 ',
#  '2014 ',
#  '2016 ',
#  '2015 ',
#  '2008 ',
#  '2017 ',
#  '2012 ',
#  '2010 ',
#  '2012 ',
#  '2009 ',
#  '2012 ',
#  '2012 ',
#  '2011 ',
#  '2015 ',
#  '2009 ',
#  '2012 ',
#  '2010 ',
#  '2016 ',
#  '2014 ',
#  '',
#  '2017 ',
#  '2011 ',
#  '2012 ',
#  '2012 ',
#  '2013 2012 ',
#  '2012 ',
#  '2008 ',
#  '2011 ',
#  '2012 ',
#  '2015 ',
#  '2012 ',
#  '2013 ',
#  '2009 ',
#  '2015 ',
#  '2010 ',
#  '2016 ',
#  '2011 ',
#  '',
#  '',
#  '2008 ',
#  '',
#  '2012 ',
#  '2015 ',
#  '',
#  '2016 ',
#  '2009 ',
#  '2012 ']

# %%
yearlist
# Out:
# ['2012']

# %%
len(Years)
# Out:
# 153

# %%
list(range(1900, 2020))
# Out:
# [1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
#  1911,
#  1912,
#  1913,
#  1914,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019]

# %%
yearlist = [str(num) for num in list(range(1900, 2020))]
yearlist
# Out:
# ['1900',
#  '1901',
#  '1902',
#  '1903',
#  '1904',
#  '1905',
#  '1906',
#  '1907',
#  '1908',
#  '1909',
#  '1910',
#  '1911',
#  '1912',
#  '1913',
#  '1914',
#  '1915',
#  '1916',
#  '1917',
#  '1918',
#  '1919',
#  '1920',
#  '1921',
#  '1922',
#  '1923',
#  '1924',
#  '1925',
#  '1926',
#  '1927',
#  '1928',
#  '1929',
#  '1930',
#  '1931',
#  '1932',
#  '1933',
#  '1934',
#  '1935',
#  '1936',
#  '1937',
#  '1938',
#  '1939',
#  '1940',
#  '1941',
#  '1942',
#  '1943',
#  '1944',
#  '1945',
#  '1946',
#  '1947',
#  '1948',
#  '1949',
#  '1950',
#  '1951',
#  '1952',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019']
