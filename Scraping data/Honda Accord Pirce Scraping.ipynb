# %%
 # Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd

# %%
csv_file_path = ("../Car price data/accord_data.csv")

# %%
# Using Splinter Scraping data
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
# URL of page to be scraped
url = 'https://losangeles.craigslist.org/search/cto?min_price=2000&auto_make_model=accord&min_auto_year=2008&max_auto_year=2018&min_auto_miles=0&max_auto_miles=1000000&condition=10&condition=20&condition=30&condition=40'

# %%
# Scrape the data based on post info
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html,"html.parser")
next_page = soup.find("a",class_ = "button next")["href"]

titles = []
prices = []
links = []
accord_data = []

while next_page:
    print(" - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - - ")
    html = browser.html
    soup = BeautifulSoup(html,"html.parser")
    results = soup.find_all('li', class_="result-row")
    
    
    
    
    for result in results:
    # Error handling
        try:
            # Identify and return title of listing
            title = result.find('a', class_="result-title").text
            # Identify and return price of listing
            price = result.a.span.text
            # Identify and return link to listing
            link = result.a['href']

            # Print results only if title, price, and link are available
            if (title and price and link):
                titles.append(title)
                prices.append(price)
                links.append(link)
                
                post_link = result.a["href"]
                response2 = requests.get(post_link)
                soup2 = BeautifulSoup(response2.text,"html.parser")
                attributes = soup2.find_all("p",class_="attrgroup")
                attribute_list = attributes[1].find_all("span")
                attr_dic = {}
                for attr in attribute_list:
                    try:
                        key,value = attr.text.split(":")
                        attr_dic[key] = value
                    except ValueError:
                        pass
    
                accord_data.append(attr_dic)
                
                
        except AttributeError as e:
            print(e)
    try:
        browser.click_link_by_partial_text('next')
        next_page = soup.find("a",class_ = "button next")["href"]
    except:
        print("- - - - - - - - - This is the last page we can find!!!- - - - - -")
        next_page = False
# Out:
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# - - - - - - - - - This is the last page we can find!!!- - - - - -

# %%
# Store info as dataframe
info_df = pd.DataFrame({
    "Info" : titles,
    "Price" : prices,
    "links" : links
})

# %%
# Show full dataframe
pd.set_option('display.max_colwidth', -1)
# Merge two dataframe
accord_df = pd.DataFrame(accord_data)
accord_df["Title"] = info_df["Info"]
accord_df["Price"] = info_df["Price"]
accord_df["links"] = info_df["links"]
accord_df.head(50)
# Out:
#                    VIN   condition     cylinders drive  fuel odometer  \
# 0    1HGCP36819A032486   like new   NaN            fwd   gas   111500
# 1   NaN                  like new    4 cylinders  NaN    gas   26000
# 2    1HGCP26499A197306   excellent   4 cylinders  NaN    gas   100000
# 3    1HGCS2B82CA001446   excellent   6 cylinders   fwd   gas   50000
# 4   NaN                  good        4 cylinders   fwd   gas   120
# 5   NaN                  excellent   4 cylinders   fwd   gas   13000
# 6   NaN                  excellent   4 cylinders   fwd   gas   11000
# 7   NaN                  like new    4 cylinders   fwd   gas   38406
# 8   NaN                  excellent   4 cylinders   rwd   gas   72000
# 9    1HGCP36829A030777   excellent  NaN           NaN    gas   108953
# 10  NaN                  good        4 cylinders   fwd   gas   108523
# 11  NaN                  like new    4 cylinders   fwd   gas   38200
# 12  NaN                  excellent   4 cylinders   fwd   gas   65400
# 13   1HGCP26499A197306   excellent   4 cylinders  NaN    gas   100000
# 14  NaN                  like new    4 cylinders  NaN    gas   102
# 15   see photo           excellent   4 cylinders   fwd   gas   80000
# 16   1HGCP26499A197306   excellent   4 cylinders  NaN    gas   100000
# 17  NaN                  excellent   4 cylinders  NaN    gas   111
# 18  NaN                  new         4 cylinders  NaN    gas   14000
# 19  NaN                  good        6 cylinders   fwd   gas   150000
# 20   1HGCR2F5XFA063578   excellent   4 cylinders   fwd   gas   35000
# 21  NaN                  like new    4 cylinders   fwd   gas   29000
# 22  NaN                  like new    4 cylinders   fwd   gas   24000
# 23  NaN                  excellent   4 cylinders   fwd   gas   155000
# 24  NaN                  excellent   6 cylinders   fwd   gas   208000
# 25  NaN                  excellent   4 cylinders   fwd   gas   94000
# 26  NaN                  like new    4 cylinders  NaN    gas   61000
# 27  NaN                  like new    4 cylinders   fwd   gas   52000
# 28  NaN                  good        4 cylinders   fwd   gas   120
# 29  NaN                  good        4 cylinders   fwd   gas   144000
# 30  NaN                  good        6 cylinders   fwd   gas   142000
# 31   1HGCR2F37EA253027   like new    4 cylinders   fwd   gas   54475
# 32   1HGCR2F37EA253027   like new    4 cylinders   fwd   gas   54475
# 33   1HGCR2F37EA253027   like new    4 cylinders   fwd   gas   54475
# 34   1HGCR2F37EA253027   like new    4 cylinders   fwd   gas   54475
# 35  NaN                  good        4 cylinders  NaN    gas   161077
# 36   1HGCP36828A023763   like new    6 cylinders  NaN    gas   158358
# 37   1HGCP26499A197306   excellent   4 cylinders  NaN    gas   100000
# 38  NaN                  new         4 cylinders   fwd   gas   25000
# 39  NaN                  excellent   4 cylinders   fwd   gas   119000
# 40  NaN                  excellent   4 cylinders   fwd   gas   73
# 41  NaN                  excellent   4 cylinders   fwd   gas   158000
# 42  NaN                  excellent  NaN           NaN    gas   95000
# 43  NaN                  like new    4 cylinders   fwd   gas   104700
# 44  NaN                  excellent   4 cylinders   fwd   gas   13000
# 45   Xxxxxxxxxxx         excellent   6 cylinders   fwd   gas   84323
# 46  NaN                  excellent   6 cylinders   fwd   gas   84245
# 47   1HGCP26499A197306   excellent   4 cylinders   fwd   gas   100000
# 48   1HGCR2F72EA172102   like new    4 cylinders  NaN    gas   56900
# 49   1HGCR2F72EA172102   like new    4 cylinders  NaN    gas   56900
#
#    paint color        size title status transmission    type  \
# 0    white       full-size   clean        automatic    sedan
# 1   NaN         NaN          salvage      automatic   NaN
# 2   NaN         NaN          clean        automatic   NaN
# 3    black       compact     salvage      automatic    coupe
# 4    silver      mid-size    salvage      automatic   NaN
# 5    silver     NaN          salvage      automatic    sedan
# 6    black      NaN          clean        automatic    sedan
# 7    black       compact     clean        manual       sedan
# 8    red         full-size   clean        automatic    sedan
# 9    grey       NaN          clean        automatic   NaN
# 10   grey        compact     clean        automatic    sedan
# 11   grey        full-size   salvage      automatic    sedan
# 12   white       mid-size    clean        automatic    coupe
# 13  NaN         NaN          clean        other       NaN
# 14   red        NaN          clean        automatic    sedan
# 15   silver      compact     salvage      automatic    sedan
# 16  NaN         NaN          clean        automatic   NaN
# 17  NaN         NaN          clean        automatic   NaN
# 18   red        NaN          rebuilt      automatic   NaN
# 19   green       full-size   clean        automatic    sedan
# 20   silver      mid-size    clean        automatic    sedan
# 21   silver      compact     salvage      automatic    sedan
# 22  NaN          compact     salvage      automatic   NaN
# 23   grey        full-size   clean        automatic    sedan
# 24   grey        compact     clean        automatic   NaN
# 25   silver     NaN          clean        automatic    coupe
# 26  NaN         NaN          salvage      automatic   NaN
# 27   green       full-size   clean        automatic    sedan
# 28   silver     NaN          salvage      automatic    sedan
# 29   white       full-size   salvage      automatic    sedan
# 30   grey        mid-size    salvage      automatic    sedan
# 31   black       compact     clean        automatic    sedan
# 32   black       compact     salvage      automatic    sedan
# 33   black       compact     clean        automatic    sedan
# 34   black       compact     clean        automatic    sedan
# 35   black      NaN          clean        automatic    sedan
# 36   black      NaN          clean        automatic   NaN
# 37  NaN         NaN          clean        automatic   NaN
# 38   blue        full-size   salvage      automatic    sedan
# 39   black       mid-size    clean        automatic   NaN
# 40  NaN         NaN          salvage      automatic   NaN
# 41   grey        full-size   clean        automatic    sedan
# 42   blue       NaN          salvage      automatic   NaN
# 43   silver      compact     clean        automatic    sedan
# 44   silver     NaN          salvage      automatic    sedan
# 45   white       compact     salvage      automatic    sedan
# 46   white       compact     salvage      automatic    sedan
# 47  NaN         NaN          clean        automatic   NaN
# 48   black      NaN          clean        automatic    sedan
# 49   black      NaN          clean        automatic    sedan
#
#                                                                      Title  \
# 0   2009 HONDA ACCORD EX-L Pearl White CLEAN TITLE Leather Seats OBO
# 1   2017 Honda Accord Sport special Edition
# 2   2009 Honda Accord LX-p 4D Sedan 100K miles *NO ACCIDENT  * XLNT
# 3   2012 Honda Accord EXL Fully Loaded
# 4   2008 honda accord
# 5   2017 Honda Accord Sport Special Edition Silver
# 6   2017 HONDA ACCORD. LX CLEAN TITLE
# 7   2014 Honda Accord Sport Model
# 8   2012 Honda Accord EX-L
# 9   2009 Honda Accord EX-L V6 4-Door Sedan
# 10  2013 Honda Accord sport
# 11  2017 HONDA ACCORD LX
# 12  2013 HONDA ACCORD EX COUPE ***ONE OF ITS KIND***
# 13  2009 HONDA ACCORD LX-p 4door 100K^ NO ACCIDENT ^ Excellent RUN!
# 14  2013 HONDA ACCORD LX CLEAN TITLE CLEAN CAR FAX
# 15  2011 Honda accord SE sedan automatic clean car!
# 16  2009 Honda Accord LX-p 4door Sedan 100K ^NO ACCIDENT ^Original OWNER
# 17  2012 Honda accord coupe
# 18  2017 HONDA ACCORD SPORT
# 19  Honda Accord V6 Ex edition
# 20  2015 HONDA ACCORD SPORT SEDAN
# 21  2016 Honda Accord Sport
# 22  2012 Honda accord exl
# 23  2012 Honda Accord
# 24  2008 Honda Accord EX fully loaded
# 25  Honda Accord 2012**cash only
# 26  Honda Accord 2015 palmdale
# 27  2013 Honda Accord for SALE!
# 28  2008 honda accord
# 29  2008 Honda Accord
# 30  Honda accord exl 2008
# 31  2014 HONDA ACCORD LX SEDAN
# 32  2014 HONDA ACCORD LX SEDAN
# 33  2014 HONDA ACCORD LX SEDAN
# 34  2014 HONDA ACCORD LX SEDAN 4D
# 35  * * 2008 HONDA ACCORD EX-L * * NAVIGATION * BLUETOOTH * CLEAN TITLE
# 36  2008 Honda accord
