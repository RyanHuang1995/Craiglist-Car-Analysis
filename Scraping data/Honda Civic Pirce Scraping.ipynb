# %%
 # Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd

# %%
csv_file_path = ("../Car price data/civic_data.csv")

# %%
# Using Splinter Scraping data
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
# URL of page to be scraped
url = 'https://losangeles.craigslist.org/search/cto?min_price=2000&auto_make_model=civic&min_auto_year=2008&max_auto_year=2018&min_auto_miles=0&max_auto_miles=1000000&condition=10&condition=20&condition=30&condition=40'

# %%
# Scrape the data based on post info
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html,"html.parser")
next_page = soup.find("a",class_ = "button next")["href"]

titles = []
prices = []
links = []
civic_data = []

while next_page:
    print(" - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - - ")
    html = browser.html
    soup = BeautifulSoup(html,"html.parser")
    results = soup.find_all('li', class_="result-row")
    
    
    
    
    for result in results:
    # Error handling
        try:
            # Identify and return title of listing
            title = result.find('a', class_="result-title").text
            # Identify and return price of listing
            price = result.a.span.text
            # Identify and return link to listing
            link = result.a['href']

            # Print results only if title, price, and link are available
            if (title and price and link):
                titles.append(title)
                prices.append(price)
                links.append(link)
                
                post_link = result.a["href"]
                response2 = requests.get(post_link)
                soup2 = BeautifulSoup(response2.text,"html.parser")
                attributes = soup2.find_all("p",class_="attrgroup")
                attribute_list = attributes[1].find_all("span")
                attr_dic = {}
                for attr in attribute_list:
                    try:
                        key,value = attr.text.split(":")
                        attr_dic[key] = value
                    except ValueError:
                        pass
    
                civic_data.append(attr_dic)
                
                
        except AttributeError as e:
            print(e)
    try:
        browser.click_link_by_partial_text('next')
        next_page = soup.find("a",class_ = "button next")["href"]
    except:
        print("- - - - - - - - - This is the last page we can find!!!- - - - - -")
        next_page = False
# Out:
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# - - - - - - - - - This is the last page we can find!!!- - - - - -

# %%
# Store info as dataframe
info_df = pd.DataFrame({
    "Info" : titles,
    "Price" : prices,
    "links" : links
})

# %%
# Show full dataframe
pd.set_option('display.max_colwidth', -1)
# Merge two dataframe
Civic_df = pd.DataFrame(civic_data)
Civic_df["Title"] = info_df["Info"]
Civic_df["Price"] = info_df["Price"]
Civic_df["links"] = info_df["links"]
Civic_df.head(50)
# Out:
#                    VIN   condition     cylinders drive     fuel odometer  \
# 0   NaN                  excellent   6 cylinders   rwd   gas      72000
# 1   NaN                  like new    4 cylinders   fwd   gas      93000
# 2   NaN                  excellent   4 cylinders   fwd   gas      133121
# 3   NaN                  excellent   4 cylinders   fwd   gas      134121
# 4    JHMFA362X9S002100   excellent   4 cylinders   fwd   gas      125074
# 5   NaN                  excellent   4 cylinders   fwd   gas      35600
# 6    19XFB2F52FE708284   excellent   4 cylinders   fwd   gas      22000
# 7   NaN                  like new    4 cylinders   fwd   gas      14000
# 8    2HGFC2F51HH506560   like new    4 cylinders   fwd   gas      17758
# 9    Hola                like new    4 cylinders   fwd   gas      48456
# 10  NaN                  excellent   4 cylinders   fwd   gas      111969
# 11  NaN                  excellent   4 cylinders  NaN    gas      72698
# 12   2HGFG3B81EH523672   excellent   4 cylinders   fwd   gas      34523
# 13  NaN                  like new    4 cylinders  NaN    gas      6000
# 14   J                   like new    4 cylinders   rwd   gas      132000
# 15  NaN                  excellent   4 cylinders   fwd   gas      59600
# 16  NaN                  good        4 cylinders   fwd   gas      80600
# 17  NaN                  excellent   4 cylinders   fwd   gas      11000
# 18  NaN                  excellent   4 cylinders  NaN    gas      66000
# 19  NaN                  excellent   4 cylinders   fwd   gas      130000
# 20   2HGFB6E50DH707632   excellent   4 cylinders   fwd   gas      46000
# 21   2HGFB2F81CH329899   good        4 cylinders   fwd   gas      71802
# 22  NaN                  excellent   4 cylinders   fwd   gas      35750
# 23   JHMFA36298S006198   excellent   4 cylinders  NaN    hybrid   126000
# 24   2HGFA1F86BH536638   excellent   4 cylinders   fwd   gas      69366
# 25  NaN                  excellent  NaN           NaN    gas      95000
# 26  NaN                  excellent  NaN           NaN    gas      22000
# 27  NaN                  excellent  NaN            fwd   gas      23600
# 28  NaN                  excellent   4 cylinders   fwd   gas      133121
# 29   2HGFA1F86BH536638   excellent   4 cylinders   fwd   gas      69366
# 30  NaN                  good        4 cylinders   fwd   gas      86000
# 31  NaN                  like new    4 cylinders  NaN    gas      105000
# 32  NaN                  like new    4 cylinders   rwd   gas      9100
# 33   19XFB5F5XEE000414   excellent   4 cylinders   fwd   other    78326
# 34  NaN                  like new    4 cylinders   fwd   gas      22250
# 35  NaN                  excellent   4 cylinders   fwd   gas      141200
# 36  NaN                  like new    4 cylinders   fwd   gas      48535
# 37  NaN                  excellent   4 cylinders   fwd   gas      90500
# 38  NaN                  excellent   4 cylinders  NaN    gas      108000
# 39  NaN                  excellent   4 cylinders   fwd   gas      32000
# 40  NaN                  excellent   4 cylinders   fwd   gas      40000
# 41  NaN                  excellent   4 cylinders   fwd   hybrid   125000
# 42  NaN                  good        6 cylinders   fwd   gas      62340
# 43   2HGFG11698H540647   excellent   4 cylinders  NaN    gas      160000
# 44   2HGFA1E66AH529431   good        4 cylinders   fwd   gas      142890
# 45  NaN                  like new    4 cylinders  NaN    gas      30986
# 46  NaN                  good        4 cylinders   fwd   gas      113000
# 47  NaN                  like new    4 cylinders   fwd   hybrid   40000
# 48  NaN                  excellent   4 cylinders   fwd   gas      26000
# 49  NaN                  excellent   4 cylinders   fwd   hybrid   40000
#
#    paint color          size title status transmission        type  \
# 0    grey        compact       clean        automatic    sedan
# 1    black       compact       clean        automatic    sedan
# 2    grey        compact       clean        automatic    coupe
# 3    silver      compact       clean        automatic    coupe
# 4    black       full-size     clean        automatic    sedan
# 5    white       compact       clean        automatic    sedan
# 6    white       compact       salvage      automatic    sedan
# 7    grey       NaN            clean        automatic    sedan
# 8    grey        full-size     clean        automatic    sedan
# 9    black       compact       salvage      automatic    sedan
# 10   grey        compact       clean        automatic    sedan
# 11   white       compact       clean        automatic    coupe
# 12   grey        compact       clean        automatic    coupe
# 13   grey       NaN            salvage      manual      NaN
# 14   grey        compact       clean        automatic    sedan
# 15   black       compact       clean        automatic    sedan
# 16   black       mid-size      salvage      automatic    sedan
# 17   green       full-size     clean        manual       coupe
# 18  NaN         NaN            salvage      automatic   NaN
# 19   silver      compact       clean        automatic    coupe
# 20   blue       NaN            clean        manual       sedan
# 21   black      NaN            clean        automatic    sedan
# 22   white       compact       clean        automatic    sedan
# 23   grey       NaN            clean        automatic    sedan
# 24   black      NaN            clean        automatic    sedan
# 25  NaN         NaN            clean        automatic   NaN
# 26   blue       NaN            clean        automatic    hatchback
# 27   black      NaN            clean        automatic   NaN
# 28   silver      full-size     clean        automatic    coupe
# 29   black       compact       clean        automatic    sedan
# 30   blue        compact       clean        manual       sedan
# 31   blue       NaN            clean        automatic   NaN
# 32   grey       NaN            salvage      automatic   NaN
# 33   silver      compact       salvage      automatic    sedan
# 34   grey        sub-compact   salvage      automatic    sedan
# 35   red         compact       clean        automatic    sedan
# 36   blue        full-size     salvage      automatic    sedan
# 37   black       compact       salvage      automatic    sedan
# 38   silver      compact       salvage      automatic   NaN
# 39   grey        compact       salvage      automatic    sedan
# 40   grey        mid-size      salvage      manual       coupe
# 41   custom      mid-size      clean        automatic    sedan
# 42   blue        mid-size      clean        automatic    sedan
# 43   black       compact       clean        manual      NaN
# 44   grey        mid-size      clean        manual       sedan
# 45  NaN         NaN            clean        automatic   NaN
# 46   white      NaN            clean        manual      NaN
# 47   grey        compact       salvage      automatic    sedan
# 48   silver     NaN            clean        automatic   NaN
# 49   grey        compact       salvage      automatic    sedan
#
#                                                                     Title  \
# 0   2012 BMW 128i convertible clean title low miles
# 1   2013 honda civic **
# 2   2008 Honda Civic Excellent Condition
# 3   2008 Honda Civic Excellent Condition
# 4   2009  honda  civic  sedan  clean  title
# 5   2015 Honda Civic SE Sedan 4D  ** Clean Title - One Owner **
# 6   2015 Honda Civic 22k miles BY OWNER
# 7   2017 HONDA CIVIC LX  CLEAN TITLE
# 8   2017 Honda Civic
# 9   2015 Honda Civic
# 10  2013 Honda Civic LX
# 11  >>> Honda Civic w Pioneer sound system and 12 inch subwoofer
# 12  2014  HONDA / CIVIC  / EX / COUPE  / LOW MILEAGE / BACK
# 13  Honda Civic Si 2017 (6kmiles)
# 14  Honda accord exl $5300 CLEAN TITLE 132,000 miles 2008 GOOD CONDITIONS
# 15  2015 Honda Civic SE Sedan 4D  ** Clean Title - One Owner **
# 16  2012 Honda civic EX 4 doors 80K miles automatic moon roof runs great
# 17  Sport 2017 Honda Civic Si 2D coupe
# 18  Honda Civic 2014
# 19  2008 HONDA CIVIC-EX, 2 DR COUPE,SUPER CLEAN ,CLEAN TITLE
# 20  2013 Honda Civic SI One Owner Clean Title
# 21  2012 Honda CIVIC EX 4D Sedan *Low 71,802 Miles* Clean Title
# 22  2015 Honda Civic SE  4D - ** Clean Title - One Owner **
# 23  2008 HONDA CIVIC HYBRID*CLEAN TITLE*Low Miles*CLEAN CAR FAX
# 24  2011 Honda Civic EX Sedan 4D
# 25  2008 Honda Civic EX 4DR Sedan with 91k miles in Excellent Condition
# 26  2015 HONDA CIVIC  (2011, 2012,2014,2013)
# 27  Excellent condition 2016 Honda Civic EX-L
# 28  2008 Honda Civic Excellent Condition
# 29  2011 Honda Civic EX Sedan
# 30  **2009 Honda Civic SI Sedan**
# 31  2012 Honda Civic
# 32  Honda Civic EX Turbo Hatchback With Self Driving Honda Sensing
# 33  2014 HONDA CIVIC GX
