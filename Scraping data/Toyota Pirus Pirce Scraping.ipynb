# %%
 # Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd

# %%
csv_file_path = ("../Car price data/prius_data.csv")

# %%
# Using Splinter Scraping data
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
# URL of page to be scraped
url = 'https://losangeles.craigslist.org/search/cto?min_price=2000&auto_make_model=Prius&min_auto_year=2008&max_auto_year=2018&min_auto_miles=0&max_auto_miles=1000000&condition=10&condition=20&condition=30&condition=40'

# %%
# Scrape the data based on post info
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html,"html.parser")
next_page = soup.find("a",class_ = "button next")["href"]

titles = []
prices = []
links = []
prius_data = []

while next_page:
    print(" - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - - ")
    html = browser.html
    soup = BeautifulSoup(html,"html.parser")
    results = soup.find_all('li', class_="result-row")
    
    
    
    
    for result in results:
    # Error handling
        try:
            # Identify and return title of listing
            title = result.find('a', class_="result-title").text
            # Identify and return price of listing
            price = result.a.span.text
            # Identify and return link to listing
            link = result.a['href']

            # Print results only if title, price, and link are available
            if (title and price and link):
                titles.append(title)
                prices.append(price)
                links.append(link)
                
                post_link = result.a["href"]
                response2 = requests.get(post_link)
                soup2 = BeautifulSoup(response2.text,"html.parser")
                attributes = soup2.find_all("p",class_="attrgroup")
                attribute_list = attributes[1].find_all("span")
                attr_dic = {}
                for attr in attribute_list:
                    try:
                        key,value = attr.text.split(":")
                        attr_dic[key] = value
                    except ValueError:
                        pass
    
                prius_data.append(attr_dic)
                
                
        except AttributeError as e:
            print(e)
    try:
        browser.click_link_by_partial_text('next')
        next_page = soup.find("a",class_ = "button next")["href"]
    except:
        print("- - - - - - - - - This is the last page we can find!!!- - - - - -")
        next_page = False
# Out:
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# - - - - - - - - - This is the last page we can find!!!- - - - - -

# %%
# Store info as dataframe
info_df = pd.DataFrame({
    "Info" : titles,
    "Price" : prices,
    "links" : links
})

# %%
# Show full dataframe
pd.set_option('display.max_colwidth', -1)
# Merge two dataframe
prius_df = pd.DataFrame(prius_data)
prius_df["Title"] = info_df["Info"]
prius_df["Price"] = info_df["Price"]
prius_df["links"] = info_df["links"]
prius_df.head(50)
# Out:
#                    VIN   condition     cylinders drive     fuel odometer  \
# 0    JTDKDTB30F1097628   excellent   4 cylinders   fwd   hybrid   23000
# 1   NaN                  excellent   4 cylinders   fwd   hybrid   54000
# 2    JTDKN3DU4A0025249   excellent   4 cylinders   fwd   hybrid   169000
# 3   NaN                  excellent   4 cylinders   fwd   hybrid   71300
# 4    JTDKN3DU1F1984075   like new    4 cylinders   fwd   hybrid   27868
# 5   NaN                  like new    4 cylinders   fwd   hybrid   20126
# 6   NaN                  good        4 cylinders   fwd   gas      49000
# 7    JTDKDTB30F1090727   like new    4 cylinders   fwd   hybrid   46341
# 8    JTDKB20U183318797   excellent   4 cylinders   fwd   hybrid   105369
# 9    jtdkn3du3f0423141   excellent   4 cylinders   fwd   hybrid   83000
# 10   jtdkn3du3f0423141   excellent   4 cylinders   fwd   hybrid   83000
# 11   jtdkn3du3f0423141   excellent   4 cylinders   fwd   hybrid   83000
# 12   jtdkn3du3f0423141   excellent   4 cylinders   fwd   hybrid   83000
# 13  NaN                  excellent   4 cylinders   fwd   hybrid   154000
# 14   JTDKN3DU7E17819     excellent   4 cylinders   fwd   hybrid   106000
# 15   jtdkn3du3f0423141   excellent   4 cylinders   fwd   hybrid   83000
# 16   JTDKB20U383386392   excellent   4 cylinders   fwd   hybrid   128195
# 17   jtdkn3du3f0423141   excellent   5 cylinders   fwd   hybrid   83200
# 18   jtdkn3du3f0423141   excellent   4 cylinders   fwd   hybrid   83200
# 19   JTDKB20U083356654   excellent   4 cylinders   fwd   hybrid   110296
# 20   jtdkn3du3f0423141   excellent   4 cylinders   fwd   hybrid   83200
# 21  NaN                  excellent   4 cylinders   fwd   hybrid   68700
# 22  NaN                  like new    4 cylinders   fwd   hybrid   60380
# 23  NaN                  good        4 cylinders   fwd   hybrid   259400
# 24  NaN                  excellent   4 cylinders   fwd   hybrid   121000
# 25  NaN                  good        4 cylinders   fwd   hybrid   33000
# 26  NaN                  excellent   4 cylinders   fwd   gas      132400
# 27   jtdkn3du3e1771692   excellent   4 cylinders   fwd   hybrid   27000
# 28   JTDKN3DU9B1461557   excellent   4 cylinders   fwd   gas      77447
# 29  NaN                  good        4 cylinders  NaN    hybrid   49000
# 30  NaN                  like new    4 cylinders   fwd   hybrid   123000
# 31  NaN                  like new    4 cylinders   fwd   hybrid   100300
# 32  NaN                  excellent   4 cylinders   fwd   hybrid   238000
# 33  NaN                  excellent   4 cylinders   fwd   gas      110000
# 34  NaN                  excellent   4 cylinders   fwd   gas      19000
# 35  NaN                  excellent   4 cylinders   fwd   hybrid   178925
# 36  NaN                  excellent   4 cylinders   fwd   gas      19000
# 37  NaN                  good        other         fwd   hybrid   108000
# 38  NaN                  excellent   4 cylinders   fwd   hybrid   83500
# 39  NaN                  excellent   4 cylinders   fwd   hybrid   53000
# 40  NaN                  excellent  NaN           NaN    gas      121000
# 41  NaN                  excellent  NaN           NaN    gas      111000
# 42   JTDKN3DU1F1984075   like new    4 cylinders   fwd   hybrid   27868
# 43  NaN                  excellent   4 cylinders   fwd   gas      75319
# 44   JTDKB20U293493094   good        4 cylinders   fwd   gas      110729
# 45   JTDKN3DU3A5101742   like new    4 cylinders  NaN    gas      141214
# 46  NaN                  excellent  NaN           NaN    gas      128000
# 47  NaN                  excellent   4 cylinders   fwd   hybrid   223900
# 48  NaN                  like new   NaN           NaN    gas      119000
# 49  NaN                  like new    4 cylinders   fwd   hybrid   20126
#
#    paint color        size title status transmission        type  \
# 0    blue        compact     clean        automatic    hatchback
# 1    blue        full-size   clean        automatic    hatchback
# 2    blue        compact     clean        automatic    hatchback
# 3    blue        compact     clean        automatic    hatchback
# 4    white       compact     clean        automatic    sedan
# 5    blue        compact     clean        automatic    hatchback
# 6    black       compact     salvage      automatic    hatchback
# 7    white       compact     clean        automatic    hatchback
# 8    grey       NaN          salvage      automatic   NaN
# 9    white       full-size   clean        automatic   NaN
# 10   white       full-size   clean        automatic   NaN
# 11   white       full-size   clean        automatic   NaN
# 12   white       full-size   clean        automatic   NaN
# 13   silver     NaN          salvage      automatic    sedan
# 14   silver      mid-size    clean        automatic    hatchback
# 15   white       full-size   clean        automatic   NaN
# 16   black      NaN          salvage      automatic   NaN
# 17   white       full-size   clean        automatic    sedan
# 18   white       full-size   clean        automatic    sedan
# 19  NaN         NaN          salvage      automatic   NaN
# 20   white       full-size   clean        automatic    sedan
# 21   grey        compact     salvage      automatic    hatchback
# 22   brown       compact     salvage      automatic    hatchback
# 23   green       compact     clean        automatic    hatchback
# 24   silver      compact     clean        automatic    hatchback
# 25   white       compact     clean        automatic    hatchback
# 26   grey        mid-size    clean        automatic    hatchback
# 27   black      NaN          clean        automatic   NaN
# 28   blue       NaN          clean        automatic    hatchback
# 29   white      NaN          clean        other       NaN
# 30   white       compact     clean        automatic    hatchback
# 31   white      NaN          clean        automatic    hatchback
# 32   silver     NaN          clean        automatic    hatchback
# 33   silver      compact     clean        automatic    sedan
# 34   silver     NaN          salvage      automatic    hatchback
# 35   green       compact     clean        automatic    hatchback
# 36   silver      compact     salvage      automatic   NaN
# 37   silver      compact     clean        automatic    sedan
# 38   white       mid-size    clean        automatic    hatchback
# 39   grey        full-size   clean        automatic    hatchback
# 40   silver     NaN          clean        automatic    hatchback
# 41   silver     NaN          salvage      automatic   NaN
# 42   white       compact     clean        automatic    sedan
# 43   black       mid-size    clean        automatic    sedan
# 44   white       compact     clean        automatic   NaN
# 45  NaN         NaN          clean        automatic   NaN
# 46   silver     NaN          clean        automatic    hatchback
# 47   white       compact     clean        automatic    hatchback
# 48   silver     NaN          clean        automatic    sedan
# 49   blue        compact     clean        automatic    hatchback
#
#                                                                     Title  \
# 0   2015 Toyota Prius C with partial extended warranty
# 1   2015 Toyota Prius -NAVIGATION/BACKUP CAMERA
# 2   2010 Toyota Prius IV
# 3   2010 Toyota Prius II Hybrid Hatchback ** Low Mileage - Clean Title **
# 4   2015 TOYOTA PRIUS II * 1owner *no accident @ 27K mile
# 5   Toyota Prius C 2016, Low Mileage , Like New , Clean Title, One Owner
# 6   sweet black 2014 prius  + low miles
# 7   2015 Toyota Prius c Four
# 8   2008 Toyota Prius fully loaded
# 9   2015 toyota prius
# 10  2015 toyota prius
# 11  2015 toyota prius
# 12  2015 toyota prius
# 13  2009 Toyota Prius Hybrid
# 14  2014 Silver Prius - Original Owner - 50MPG
# 15  2015 toyota prius
# 16  2008 Toyota Prius Touring Edition
# 17  2015 toyota prius
# 18  2015 toyota prius
# 19  2007 Toyota Prius Touring Edition
# 20  2015 toyota prius
# 21  2011 TOYOTA PRIUS LOW MILES 68K ORIGINAL
# 22  2010 TOYOTA PRIUS GOLD ONLY 60k original miles
# 23  2011 toyota prius
# 24  2015 toyota prius c 2 clean title fully maintained mint condition
# 25  toyota prius 3 2015 low miles clean title one owner !!!! warranty
# 26  Toyota Prius Hybrido 2014
# 27  2014 Toyota Prius Low Mileage with Sunroof
# 28  2011 Toyota Prius ... Only 77K Miles ... Excellent Shape ... Must See
# 29  Toyota Prius
# 30  Toyota Prius hybrid 2012, Only 123mil.
# 31  2013 Toyota Prius V original owner no accident
# 32  2008 Toyota Prius
# 33  2013 Toyota Prius
# 34  2017 Toyota Prius Four Hybrid Leather Camera Sonar LKA GPS 19k mi.
# 35  2009 Toyota Prius clean title clean carfax camera 178k
