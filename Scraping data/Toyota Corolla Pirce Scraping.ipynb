# %%
 # Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd

# %%
csv_file_path = ("../Car price data/corolla_data.csv")

# %%
# Using Splinter Scraping data
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
# URL of page to be scraped
url = 'https://losangeles.craigslist.org/search/cto?min_price=2000&auto_make_model=Corolla&min_auto_year=2008&max_auto_year=2018&min_auto_miles=0&max_auto_miles=1000000&condition=10&condition=20&condition=30&condition=40'

# %%
# Scrape the data based on post info
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html,"html.parser")
next_page = soup.find("a",class_ = "button next")["href"]

titles = []
prices = []
links = []
corolla_data = []

while next_page:
    print(" - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - - ")
    html = browser.html
    soup = BeautifulSoup(html,"html.parser")
    results = soup.find_all('li', class_="result-row")
    
    
    
    
    for result in results:
    # Error handling
        try:
            # Identify and return title of listing
            title = result.find('a', class_="result-title").text
            # Identify and return price of listing
            price = result.a.span.text
            # Identify and return link to listing
            link = result.a['href']

            # Print results only if title, price, and link are available
            if (title and price and link):
                titles.append(title)
                prices.append(price)
                links.append(link)
                
                post_link = result.a["href"]
                response2 = requests.get(post_link)
                soup2 = BeautifulSoup(response2.text,"html.parser")
                attributes = soup2.find_all("p",class_="attrgroup")
                attribute_list = attributes[1].find_all("span")
                attr_dic = {}
                for attr in attribute_list:
                    try:
                        key,value = attr.text.split(":")
                        attr_dic[key] = value
                    except ValueError:
                        pass
    
                corolla_data.append(attr_dic)
                
                
        except AttributeError as e:
            print(e)
    try:
        browser.click_link_by_partial_text('next')
        next_page = soup.find("a",class_ = "button next")["href"]
    except:
        print("- - - - - - - - - This is the last page we can find!!!- - - - - -")
        next_page = False
# Out:
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# - - - - - - - - - This is the last page we can find!!!- - - - - -

# %%
# Store info as dataframe
info_df = pd.DataFrame({
    "Info" : titles,
    "Price" : prices,
    "links" : links
})

# %%
# Show full dataframe
pd.set_option('display.max_colwidth', -1)
# Merge two dataframe
corolla_df = pd.DataFrame(corolla_data)
corolla_df["Title"] = info_df["Info"]
corolla_df["Price"] = info_df["Price"]
corolla_df["links"] = info_df["links"]
corolla_df.head(50)
# Out:
#                    VIN   condition     cylinders drive  fuel odometer  \
# 0    5YFBURHE3EP002971   excellent   4 cylinders   fwd   gas   107600
# 1    5YFBU4EEXDP214711   like new    4 cylinders   fwd   gas   46000
# 2   NaN                  excellent   4 cylinders   fwd   gas   131360
# 3   NaN                  good        4 cylinders   fwd   gas   117500
# 4    1NXBU40E19Z148949   good        4 cylinders   fwd   gas   187310
# 5   NaN                  excellent   4 cylinders  NaN    gas   129000
# 6   NaN                  like new    4 cylinders   fwd   gas   115800
# 7    5YFBURHEXGP458579   excellent   4 cylinders   fwd   gas   50000
# 8    5YFBURHE6HP627501   excellent   4 cylinders   fwd   gas   44800
# 9   NaN                  excellent   4 cylinders  NaN    gas   128000
# 7    blue        compact     salvage      automatic    sedan
# 8    grey        compact     clean        automatic    sedan
# 9   NaN         NaN          clean        automatic   NaN
# 10   black       compact     salvage      automatic    sedan
# 11   white      NaN          clean        automatic   NaN
# 12  NaN         NaN          clean        automatic   NaN
# 13  NaN         NaN          clean        automatic   NaN
# 14  NaN         NaN          clean        automatic   NaN
# 15   black       compact     clean        automatic    sedan
# 16  NaN         NaN          clean        automatic   NaN
# 17  NaN         NaN          clean        automatic   NaN
# 18   blue        compact     salvage      automatic    sedan
# 19   green       compact     salvage      automatic    sedan
# 20   white       compact     clean        automatic    sedan
# 21  NaN         NaN          clean        automatic   NaN
# 22   black       mid-size    clean        automatic    sedan
# 23  NaN         NaN          clean        automatic   NaN
# 24   silver      compact     clean        automatic    sedan
# 25  NaN         NaN          clean        automatic   NaN
# 26  NaN         NaN          clean        automatic   NaN
# 27   silver     NaN          clean        automatic    sedan
# 28  NaN         NaN          clean        automatic   NaN
# 29   grey        compact     clean        automatic    sedan
# 30  NaN         NaN          clean        automatic   NaN
# 31   white       mid-size    clean        automatic    sedan
# 32   silver     NaN          clean        automatic    sedan
# 33  NaN         NaN          clean        automatic   NaN
# 34   blue        compact     clean        automatic    sedan
# 35   black      NaN          clean        automatic   NaN
# 36  NaN         NaN          clean        automatic   NaN
# 37  NaN         NaN          clean        automatic   NaN
# 38  NaN         NaN          clean        automatic   NaN
# 39  NaN         NaN          clean        automatic   NaN
# 40  NaN         NaN          clean        automatic   NaN
# 41   black       full-size   clean        automatic    sedan
# 42   silver      compact     clean        automatic    sedan
# 43  NaN         NaN          clean        automatic   NaN
# 44  NaN         NaN          clean        automatic   NaN
# 45   black       compact     clean        automatic    sedan
# 46   black       compact     clean        automatic    sedan
# 47   black       compact     clean        automatic    sedan
# 48   black       compact     clean        automatic    sedan
# 49   black       compact     clean        automatic    sedan
#
#                                                                     Title  \
# 0   2014 Toyota Corolla LE
# 1   2013 Toyota Corolla LE, 46k miles 1 owner, like new, only next 4 days
# 2   2010 Toyota Corolla S sedan súper clean
# 3   2008 Toyota Corolla CE
# 4   2009 Toyota Corolla S
# 5   2012 Toyota Corolla LE 4 Cylinders
# 6   2010 Toyota Corolla LE- $7700
# 7   2016 Toyota Corolla S 2017
# 8   2017 Toyota Corolla L - 4D Sedan ** One Owner - Clean Title **
# 9   2012 toyota corolla
# 10  2012 TOYOTA COROLLA S 56k miles $6300$
# 11  2014 Toyota Corolla
# 12  2012 toyota corolla
# 13  2012 toyota corolla
# 14  2012 toyota corolla
# 15  2010 Toyota Corolla LE
# 16  2012 Toyota Corolla LE 4 Cylinders
# 17  2012 toyota corolla
# 18  2013 TOYOTA  COROLLA  LE.
# 19  2014 TOYOTA  COROLLA  LE
# 20  2013 Toyota Corolla LE
# 21  2012 toyota corolla
# 22  2010 Toyota Corolla S loaded one owner runs great gas saver
# 23  2012 toyota corolla
# 24  2010 Toyota Corolla LE in excellent condition!
# 25  2012 Toyota Corolla LE 4 Cylinders
# 26  2012 toyota corolla
# 27  2015 Toyota COROLLA L *50K Miles* 1.8L I4  No Accident / Damage
# 28  2012 toyota corolla
# 29  2017 Toyota Corolla L  Sedan ** Clean Title - One Owner **
# 30  2012 Toyota Corolla LE 4 Cylinders
# 31  2010 Toyota Corolla LE- $7700
# 32  2015 Toyota COROLLA L *Low 35,053 Miles*
# 33  2012 toyota corolla
# 34  2009 Toyota Corolla
# 35  2013 TOYOTA COROLLA SPORT
# 36  2018 Toyota Corolla LE..ONLY 12K MILES.FACTORY WARRANTY.NEW
# 37  2012 toyota corolla
# 38  2012 Toyota Corolla LE 4 Cylinders
# 39  2012 Toyota Corolla LE 4 Cylinders
# 40  2012 toyota corolla
# 41  2009 Toyota Corolla LE excellent condition
# 42  2013 Toyota Corolla Sport (low miles)
# 43  2012 Toyota Corolla LE 4 Cylinders
# 44  2012 Toyota Corolla LE 4 Cylinders
# 45  2014 TOYOTA COROLLA S 4D SEDAN
# 46  2014 TOYOTA COROLLA S SEDAN
# 47  2014 TOYOTA COROLLA S SEDAN 4D
# 48  2014 TOYOTA COROLLA S SEDAN 4D
# 49  2014 TOYOTA COROLLA S SEDAN 4D
#
#      Price  \
# 0   $9200
# 1   $9800
# 2   $6950
# 3   $4999
# 4   $6500
# 5   $6800
# 6   $7700
# 7   $10800
# 8   $13750
# 9   $6800
# 10  $6200
# 11  $14000
# 12  $6800
# 13  $6800
# 14  $6800
# 15  $7499
# 16  $7000
# 17  $6800
# 18  $6950
# 19  $8600
# 20  $6999
# 21  $6800
# 22  $6600
# 23  $6800
# 24  $5799
# 25  $7000
# 26  $6800
# 27  $11900
# 28  $6800
# 29  $13750
# 30  $7000
# 31  $7700
# 32  $11900
# 33  $6800
# 34  $5600
# 35  $7500
# 36  $15888
# 37  $6800
# 38  $7000
# 39  $6800
# 40  $6800
# 41  $6800
# 42  $15000
# 43  $6800
# 44  $6800
# 45  $12900
# 46  $12900
# 47  $12900
# 48  $12900
# 49  $12900
#
#                                                                                         links
# 0   https://losangeles.craigslist.org/sfv/cto/d/2014-toyota-corolla-le/6694243548.html
# 1   https://losangeles.craigslist.org/sgv/cto/d/2013-toyota-corolla-le-46k/6710014378.html
# 2   https://losangeles.craigslist.org/sgv/cto/d/2010-toyota-corolla-sedan/6709987427.html
# 3   https://losangeles.craigslist.org/sfv/cto/d/2008-toyota-corolla-ce/6709937604.html
# 4   https://losangeles.craigslist.org/sgv/cto/d/2009-toyota-corolla/6709915166.html
# 5   https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla-le-4/6707704651.html
# 6   https://losangeles.craigslist.org/wst/cto/d/2010-toyota-corolla-le-7700/6709768318.html
# 7   https://losangeles.craigslist.org/sfv/cto/d/2016-toyota-corolla-2017/6709743969.html
# 8   https://losangeles.craigslist.org/lac/cto/d/2017-toyota-corolla-4d-sedan/6709749150.html
# 9   https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corol