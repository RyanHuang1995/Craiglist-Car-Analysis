# %%
 # Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd

# %%
csv_file_path = ("../Car price data/altima_data.csv")

# %%
# Using Splinter Scraping data
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
# URL of page to be scraped
url = 'https://losangeles.craigslist.org/search/cto?min_price=2000&auto_make_model=Altima&min_auto_year=2008&max_auto_year=2018&min_auto_miles=0&max_auto_miles=1000000&condition=10&condition=20&condition=30&condition=40'

# %%
# Scrape the data based on post info
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html,"html.parser")
next_page = soup.find("a",class_ = "button next")["href"]

titles = []
prices = []
links = []
car_data = []

while next_page:
    print(" - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - - ")
    html = browser.html
    soup = BeautifulSoup(html,"html.parser")
    results = soup.find_all('li', class_="result-row")
    
    
    
    
    for result in results:
    # Error handling
        try:
            # Identify and return title of listing
            title = result.find('a', class_="result-title").text
            # Identify and return price of listing
            price = result.a.span.text
            # Identify and return link to listing
            link = result.a['href']

            # Print results only if title, price, and link are available
            if (title and price and link):
                titles.append(title)
                prices.append(price)
                links.append(link)
                
                post_link = result.a["href"]
                response2 = requests.get(post_link)
                soup2 = BeautifulSoup(response2.text,"html.parser")
                attributes = soup2.find_all("p",class_="attrgroup")
                attribute_list = attributes[1].find_all("span")
                attr_dic = {}
                
                try:
                
                    tag = attributes[0].find("span").find("b").text.split(" ")
                
                    yearlist = [str(num) for num in list(range(1900, 2020))]
                    for word in tag:
                        if word in yearlist:
                            year = word
                            for attr in attribute_list:
                                try:
                                    key,value = attr.text.split(":")
                                    attr_dic[key] = value
                                    attr_dic["Year"] = year
                                except ValueError:
                                    pass
                            if word not in tag:
                                attr_dic["Year"] = "NA"
                    
                    
                except:
                    attr_dic["Year"] = "NA"
                
    
                car_data.append(attr_dic)
                
                
        except AttributeError as e:
            print(e)
    try:
        browser.click_link_by_partial_text('next')
        next_page = soup.find("a",class_ = "button next")["href"]
    except:
        print("- - - - - - - - - This is the last page we can find!!!- - - - - -")
        next_page = False
# Out:
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'

# %%
# Store info as dataframe
info_df = pd.DataFrame({
    "Info" : titles,
    "Price" : prices,
    "links" : links
})

# %%
# Show full dataframe
pd.set_option('display.max_colwidth', -1)
# Merge two dataframe
car_df = pd.DataFrame(car_data)
car_df["Title"] = info_df["Info"]
car_df["Price"] = info_df["Price"]
car_df["Link"] = info_df["links"]
car_df["Make"] = "Nissan"
car_df["Model"] = "Altima"
car_df = car_df[['Title','Make', 'Model','Year', 'condition', 'cylinders', 'drive', 'fuel', 'odometer',
       'paint color', 'size', 'title status', 'transmission', 'type', 
       'Price', 'VIN', 'Link']]
car_df.head(50)
# Out:
#                                                                     Title  \
# 0   2014 Nissan Altima 2.5 s
# 1   2014 Nissan Altima
# 2   2014 Nissan Altima 2.5 s
# 46  Nissan  Altima  2015   like new    4 cylinders   fwd   gas      48400
# 47  Nissan  Altima  2008   excellent   4 cylinders   fwd   gas      48745
# 48  Nissan  Altima  2008   good        4 cylinders   4wd   gas      181000
# 49  Nissan  Altima  2009   excellent   4 cylinders   fwd   gas      59400
#
#    paint color        size title status transmission    type   Price  \
# 0    brown       mid-size    clean        automatic    sedan  $9500
# 1    brown       mid-size    clean        automatic    sedan  $9500
# 2    brown       mid-size    clean        automatic    sedan  $9500
# 3    brown       mid-size    clean        automatic    sedan  $9500
# 4    brown       mid-size    clean        automatic    sedan  $9500
# 5    custom      compact     clean        automatic    sedan  $5500
# 6    silver      mid-size    clean        automatic    sedan  $4450
# 7    black      NaN          clean        automatic   NaN     $5900
# 8   NaN          compact     clean        automatic   NaN     $3999
# 9    white       mid-size    clean        automatic    sedan  $7495
# 10  NaN         NaN          clean        automatic   NaN     $8500
# 11  NaN         NaN          clean        automatic   NaN     $8700
# 12  NaN         NaN          clean        automatic    sedan  $5800
# 13   black       mid-size    clean        automatic    sedan  $16400
# 14   silver      compact     salvage      automatic    sedan  $4250
# 15  NaN         NaN          clean        automatic   NaN     $6500
# 16   grey        full-size   clean        automatic    sedan  $15499
# 17  NaN         NaN          clean        automatic   NaN     $9995
# 18   silver      full-size   clean        automatic    sedan  $12950
# 19   silver      full-size   clean        automatic    sedan  $12900
# 20   silver      full-size   clean        automatic    sedan  $12950
# 21   black       full-size   clean        automatic    sedan  $8900
# 22  NaN         NaN          clean        automatic   NaN     $9500
# 23   yellow      mid-size    clean        automatic    sedan  $8450
# 24  NaN         NaN          clean        automatic    sedan  $16000
# 25   grey        full-size   salvage      automatic    sedan  $10300
# 26   white      NaN          clean        automatic    sedan  $6000
# 27   black       full-size   clean        automatic    sedan  $12500
# 28  NaN         NaN          clean        automatic   NaN     $7000
# 29   black      NaN          clean        automatic    coupe  $8499
# 30   black       mid-size    clean        automatic    sedan  $11500
# 31   silver      compact     salvage      automatic    sedan  $4250
# 32   grey        mid-size    clean        automatic    sedan  $6000
# 33   brown       mid-size    clean        automatic    sedan  $7200
# 34   grey        full-size   clean        automatic    sedan  $4490
# 35   silver      full-size   clean        automatic    sedan  $6800
# 36   grey       NaN          clean        automatic   NaN     $12900
# 37   blue        compact     clean        automatic    sedan  $15500
# 38   silver      full-size   clean        automatic    sedan  $13900
# 39   grey        compact     clean        automatic    coupe  $7800
# 40   grey        mid-size    clean        automatic    sedan  $15200
# 41   black      NaN          clean        automatic   NaN     $9500
# 42  NaN         NaN          clean        automatic   NaN     $9995
# 43   silver      mid-size    clean        automatic    coupe  $4900
# 44   silver      compact     clean        automatic    sedan  $5600
# 45   grey       NaN          clean        automatic    sedan  $5000
# 46   black       mid-size    clean        automatic    sedan  $9900
# 47  NaN         NaN          clean        automatic    sedan  $7499
# 48   red        NaN          clean        automatic    sedan  $2299
# 49   white       compact     salvage      automatic    sedan  $4500
#
#                    VIN  \
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 