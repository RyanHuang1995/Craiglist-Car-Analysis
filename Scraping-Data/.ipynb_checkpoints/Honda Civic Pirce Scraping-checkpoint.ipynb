# %%
 # Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd

# %%
csv_file_path = ("../Car price data/civic_data.csv")

# %%
# Using Splinter Scraping data
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
# URL of page to be scraped
url = 'https://losangeles.craigslist.org/search/cto?min_price=2000&auto_make_model=civic&min_auto_year=2008&max_auto_year=2018&min_auto_miles=0&max_auto_miles=1000000&condition=10&condition=20&condition=30&condition=40'

# %%
# Scrape the data based on post info
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html,"html.parser")
next_page = soup.find("a",class_ = "button next")["href"]

titles = []
prices = []
links = []
car_data = []

while next_page:
    print(" - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - - ")
    html = browser.html
    soup = BeautifulSoup(html,"html.parser")
    results = soup.find_all('li', class_="result-row")
    
    
    
    
    for result in results:
    # Error handling
        try:
            # Identify and return title of listing
            title = result.find('a', class_="result-title").text
            # Identify and return price of listing
            price = result.a.span.text
            # Identify and return link to listing
            link = result.a['href']

            # Print results only if title, price, and link are available
            if (title and price and link):
                titles.append(title)
                prices.append(price)
                links.append(link)
                
                post_link = result.a["href"]
                response2 = requests.get(post_link)
                soup2 = BeautifulSoup(response2.text,"html.parser")
                attributes = soup2.find_all("p",class_="attrgroup")
                attribute_list = attributes[1].find_all("span")
                attr_dic = {}
                
                try:
                
                    tag = attributes[0].find("span").find("b").text.split(" ")
                
                    yearlist = [str(num) for num in list(range(1900, 2020))]
                    for word in tag:
                        if word in yearlist:
                            year = word
                            for attr in attribute_list:
                                try:
                                    key,value = attr.text.split(":")
                                    attr_dic[key] = value
                                    attr_dic["Year"] = year
                                except ValueError:
                                    pass
                            if word not in tag:
                                attr_dic["Year"] = "NA"
                    
                    
                except:
                    attr_dic["Year"] = "NA"
                
    
                car_data.append(attr_dic)
                
                
        except AttributeError as e:
            print(e)
    try:
        browser.click_link_by_partial_text('next')
        next_page = soup.find("a",class_ = "button next")["href"]
    except:
        print("- - - - - - - - - This is the last page we can find!!!- - - - - -")
        next_page = False
# Out:
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# - - - - - - - - - This is the last page we can find!!!- - - - - -

# %%
# Store info as dataframe
info_df = pd.DataFrame({
    "Info" : titles,
    "Price" : prices,
    "links" : links
})

# %%
# Show full dataframe
pd.set_option('display.max_colwidth', -1)
# Merge two dataframe
car_df = pd.DataFrame(car_data)
car_df["Title"] = info_df["Info"]
car_df["Price"] = info_df["Price"]
car_df["Link"] = info_df["links"]
car_df["Make"] = "Toyota"
car_df["Model"] = "Civic"
car_df = car_df[['Title','Make', 'Model','Year', 'condition', 'cylinders', 'drive', 'fuel', 'odometer',
       'paint color', 'size', 'title status', 'transmission', 'type', 
       'Price', 'VIN', 'Link']]
car_df.head(50)
# Out:
#                                                                     Title  \
# 0   2012 Honda civic EX 4 doors 80K miles automatic moon roof runs great
# 1   2016 Honda Civic LX
# 2   Honda Civic EXl Turbo Hatchback Honda Sensing 40mpg
# 4   Toyota  Civic  2018   good        4 cylinders   fwd   gas      2250
# 5   Toyota  Civic  2012   like new    4 cylinders  NaN    gas      82000
# 6   Toyota  Civic  2014   like new    4 cylinders  NaN    gas      81
# 7   Toyota  Civic  2013   excellent   4 cylinders   fwd   gas      150000
# 8   Toyota  Civic  2015   excellent   4 cylinders   fwd   gas      59600
# 9   Toyota  Civic  2008   excellent   4 cylinders  NaN    gas      160000
# 10  Toyota  Civic  2012   excellent   4 cylinders   fwd   gas      46000
# 11  Toyota  Civic  2008   excellent   4 cylinders   rwd   gas      89300
# 12  Toyota  Civic  2014   like new    4 cylinders  NaN    gas      81
# 13  Toyota  Civic  2008   excellent   4 cylinders   fwd   hybrid   145000
# 14  Toyota  Civic  2012   excellent   4 cylinders   fwd   gas      88783
# 15  Toyota  Civic  2008   good       NaN            fwd   gas      149657
# 16  Toyota  Civic  2012   good        4 cylinders  NaN    gas      101992
# 17  Toyota  Civic  2017   excellent   4 cylinders  NaN    gas      11000
# 18  Toyota  Civic  2012   like new    4 cylinders  NaN    gas      82000
# 19  Toyota  Civic  2008   excellent  NaN           NaN    gas      120000
# 20  Toyota  Civic  2010   excellent   4 cylinders  NaN    gas      120000
# 21  Toyota  Civic  2012   good        4 cylinders  NaN    gas      62347
# 22  Toyota  Civic  2012   like new    4 cylinders   fwd   hybrid   40000
# 23  Toyota  Civic  2012   excellent   4 cylinders  NaN    gas      132000
# 24  Toyota  Civic  2012   excellent   6 cylinders   rwd   gas      72000
# 25  Toyota  Civic  2013   like new    4 cylinders   fwd   gas      93000
# 26  Toyota  Civic  2008   excellent   4 cylinders   fwd   gas      133121
# 27  Toyota  Civic  2008   excellent   4 cylinders   fwd   gas      134121
# 28  Toyota  Civic  2015   excellent   4 cylinders   fwd   gas      22000
# 29  Toyota  Civic  2017   like new    4 cylinders   fwd   gas      14000
# 30  Toyota  Civic  2017   like new    4 cylinders   fwd   gas      17758
# 31  Toyota  Civic  2015   like new    4 cylinders   fwd   gas      48456
# 32  Toyota  Civic  2013   excellent   4 cylinders   fwd   gas      111969
# 33  Toyota  Civic  2008   excellent   4 cylinders  NaN    gas      72698
# 34  Toyota  Civic  2014   excellent   4 cylinders   fwd   gas      34523
# 35  Toyota  Civic  2017   like new    4 cylinders  NaN    gas      6000
# 36  Toyota  Civic  2008   like new    4 cylinders   rwd   gas      132000
# 37  Toyota  Civic  2015   excellent   4 cylinders   fwd   gas      59600
# 38  Toyota  Civic  2012   good        4 cylinders   fwd   gas      80600
# 39  Toyota  Civic  2008   excellent   4 cylinders   fwd   gas      130000
# 40  Toyota  Civic  2013   excellent   4 cylinders   fwd   gas      46000
# 41  Toyota  Civic  2012   good        4 cylinders   fwd   gas      71802
# 42  Toyota  Civic  2008   excellent   4 cylinders  NaN    hybrid   126000
# 43  Toyota  Civic  2011   excellent   4 cylinders   fwd   gas      69366
# 44  Toyota  Civic  2008   excellent  NaN           NaN    gas      95000
# 45  Toyota  Civic  2015   excellent  NaN           NaN    gas      22000
# 46  Toyota  Civic  2016   excellent  NaN            fwd   gas      23600
# 47  Toyota  Civic  2008   excellent   4 cylinders   fwd   gas      133121
# 48  Toyota  Civic  2011   excellent   4 cylinders   fwd   gas      69366
# 49  Toyota  Civic  2009   good        4 cylinders   fwd   gas      86000
#
#    paint color          size title status transmission          type   Price  \
# 0    black       mid-size      salvage      automatic    sedan        $5000
# 1    grey        sub-compact   salvage      automatic    sedan        $11495
# 2    grey       NaN            salvage      automatic   NaN           $14200
# 3   NaN         NaN            clean        manual       sedan        $14500
# 4    blue        mid-size      clean        automatic    sedan        $24344
# 5    black      NaN            salvage      automatic   NaN           $6900
# 6   NaN         NaN            salvage      automatic   NaN           $7500
# 7    black      NaN            salvage      automatic   NaN           $4000
# 8    black       compact       clean        automatic    sedan        $12500
# 9    black       compact       clean        manual      NaN           $4100
# 10   brown       compact       salvage      automatic    sedan        $6800
# 11   silver      compact       clean        automatic    sedan        $6800
# 12  NaN         NaN            salvage      automatic   NaN           $7500
# 13   yellow      mid-size      clean        automatic    sedan        $5500
# 14   blue        mid-size      clean        automatic    sedan        $10499
# 15   blue        compact       clean        automatic    sedan        $4500
# 16   grey       NaN            clean        automatic    coupe        $7200
# 17   green       full-size     clean        manual       convertible  $17600
# 18   black      NaN            salvage      automatic   NaN           $6900
# 19  NaN         NaN            clean        automatic    sedan        $5800
# 20  NaN         NaN            clean        automatic    sedan        $6800
# 21  NaN         NaN            clean        automatic   NaN           $10600
# 22   grey        compact       salvage      automatic    sedan        $7400
# 23  NaN         NaN            clean        automatic    sedan        $7800
# 24   grey        compact       clean        automatic    sedan        $13000
# 25   black       compact       clean        automatic    sedan        $8900
# 26   grey        compact       clean        automatic    coupe        $4900
# 27   silver      compact       clean        automatic    coupe        $4900
# 28   white       compact       salvage      automatic    sedan        $10000
# 29   grey       NaN            clean        automatic    sedan        $14900
# 30   grey        full-size     clean        automatic    sedan        $15500
# 31   black       compact       salvage      automatic    sedan        $10500
# 32   grey        compact       clean        automatic    sedan        $8750
# 33   white       compact       clean        automatic    coupe        $6500
# 34   grey        compact       clean        automatic    coupe        $13995
# 35   grey       NaN            salvage      manual      NaN           $15500
# 36   grey        compact       clean        automatic    sedan        $5300
# 37   black       compact       clean        automatic    sedan        $12500
# 38   black       mid-size      salvage      automatic    sedan        $5000
# 39   silver      compact       clean        automatic    coupe        $5300
# 40   blue       NaN            clean        manual       sedan        $14500
# 41   black      NaN            clean        automatic    sedan        $9900
# 42   grey       NaN            clean        automatic    sedan        $5390
# 43   black      NaN            clean        automatic    sedan        $9999
# 44  NaN         NaN            clean        automatic   NaN           $7550
# 45   blue       NaN            clean        automatic    hatchback    $10999
# 46   black      NaN            clean        automatic   NaN           $17950
# 47   silver      full-size     clean        automatic    coupe        $4900
# 48   black       compact       clean        automatic    sedan        $9999
# 49   blue        compact       clean        manual       sedan        $10500
#
#                    VIN  \
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 