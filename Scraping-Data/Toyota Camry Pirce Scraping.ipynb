# %%
 # Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd

# %%
csv_file_path = ("../Car price data/camry_data.csv")

# %%
# Using Splinter Scraping data
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
# URL of page to be scraped
url = 'https://losangeles.craigslist.org/search/cto?min_price=2000&auto_make_model=CAMRY&min_auto_year=2008&max_auto_year=2018&min_auto_miles=0&max_auto_miles=1000000&condition=10&condition=20&condition=30&condition=40'

# %%
# Scrape the data based on post info
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html,"html.parser")
next_page = soup.find("a",class_ = "button next")["href"]

titles = []
prices = []
links = []
car_data = []

while next_page:
    print(" - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - - ")
    html = browser.html
    soup = BeautifulSoup(html,"html.parser")
    results = soup.find_all('li', class_="result-row")
    
    
    
    
    for result in results:
    # Error handling
        try:
            # Identify and return title of listing
            title = result.find('a', class_="result-title").text
            # Identify and return price of listing
            price = result.a.span.text
            # Identify and return link to listing
            link = result.a['href']

            # Print results only if title, price, and link are available
            if (title and price and link):
                titles.append(title)
                prices.append(price)
                links.append(link)
                
                post_link = result.a["href"]
                response2 = requests.get(post_link)
                soup2 = BeautifulSoup(response2.text,"html.parser")
                attributes = soup2.find_all("p",class_="attrgroup")
                attribute_list = attributes[1].find_all("span")
                attr_dic = {}
                
                try:
                
                    tag = attributes[0].find("span").find("b").text.split(" ")
                
                    yearlist = [str(num) for num in list(range(1900, 2020))]
                    for word in tag:
                        if word in yearlist:
                            year = word
                            for attr in attribute_list:
                                try:
                                    key,value = attr.text.split(":")
                                    attr_dic[key] = value
                                    attr_dic["Year"] = year
                                except ValueError:
                                    pass
                            if word not in tag:
                                attr_dic["Year"] = "NA"
                    
                    
                except:
                    attr_dic["Year"] = "NA"
                
    
                car_data.append(attr_dic)
                
                
        except AttributeError as e:
            print(e)
    try:
        browser.click_link_by_partial_text('next')
        next_page = soup.find("a",class_ = "button next")["href"]
    except:
        print("- - - - - - - - - This is the last page we can find!!!- - - - - -")
        next_page = False
# Out:
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# - - - - - - - - - This is the last page we can find!!!- - - - - -

# %%
# Store info as dataframe
info_df = pd.DataFrame({
    "Info" : titles,
    "Price" : prices,
    "links" : links
})

# %%
# Show full dataframe
pd.set_option('display.max_colwidth', -1)
# Merge two dataframe
car_df = pd.DataFrame(car_data)
car_df["Title"] = info_df["Info"]
car_df["Price"] = info_df["Price"]
car_df["Link"] = info_df["links"]
car_df["Make"] = "Toyota"
car_df["Model"] = "Camry"
car_df = car_df[['Title','Make', 'Model','Year', 'condition', 'cylinders', 'drive', 'fuel', 'odometer',
       'paint color', 'size', 'title status', 'transmission', 'type', 
       'Price', 'VIN', 'Link']]
car_df.head(50)
# Out:
#                                                                      Title  \
# 0   2017 Camry SE
# 1   2015 Toyota Cambry hybrid
# 2   2014 Toyota Camry SE
# 3   2014 Toyota Camry SE
# 4   2012 Toyota Camry LE
# 5   Toyota Camry Le 2008
# 6   2008  Toyota Camry XLE- V6 - Low miles-excellent condition
# 7   Toyota Camry LE  2009 (Woodland Hills) 4650$
# 8   2008 TOYOTA CAMRY LE EXCELLENT CONDITION NICE SPORT CAR GOOD DEAL
# 9   TOYOTA  CAMRY  2009
# 10  2011 TOYOTA CAMRY LE
# 11  2011 TOYTA CAMRY LE 64KMI ORIGI MI EXCE COND CLEAN TITLE SELL BY OWNER
# 12  Toyota Camry año 2015 .SE.
# 13  2014 Toyota Camry SE Sport 70k One Owner
# 14  2018 Toyota Camry LE 4 Door Sedan Like New Perfect Fully Loaded
# 15  2014 Toyota Camry XLE Luxury Model - 6 Cylinder - Clean - NOT Salvaged
# 16  Toyota Camry as 2013
# 17  2008 Toyota Camry hybrid xle
# 18  2011 Toyota Camry
# 19  2012 Toyota camry se
# 20  2016 Toyota Camry Special Edition
# 21  2014 Toyota corolla
# 22  2012 TOYOTA CAMRY
# 23  2013 toyota camry se sport clean title low miles
# 24  2011 TOYOTA CAMRY
# 25  2014 toyota camry, only 29k miles, 1 owner, clean title
# 26  2014 toyota camry, only 29k miles, 1 owner, clean title
# 27  2014 toyota camry, only 29k miles, 1 owner, clean title
# 28  2010 Toyota Camry LE $$$ 6,800
# 29  2008 TOYOTA CAMRY LE/
# 30  2009 Toyota camry LE..clean title/carfax
# 31  2018 Toyota Camry LE 4 Door Sedan Like New Low Mileage w/ Warranty
# 32  2017 Toyota Camry SE Clean title only 14k miles
# 33  2008 Toyota Camry hybrid xle
# 34  2014 Toyota Camry SE Sedan 4D Auto 6-Speed *Low 61,007 Miles*
# 35  2009 toyota camry
# 36  2009 toyota camry
# 37  2016 TOYOTA CAMRY SE
# 38  2017 TOYOTA CAMRY SE
# 39  2014 Toyota Camry
# 40  Toyota Camry 2009
# 41  Toyota Camry se
# 42  Toyota Camry 2009
# 43  2014 toyota Camry
# 44  2012 Toyota Camry SE / Really Powerful
# 45  2009 Toyota Camry
# 46  2011 Toyota Camry LE -CLEAN TITLE -$7500
# 47  2010 Toyota Camry LE sedan
# 48  clean title one owner
# 49  2014 TOYOTA CAMRY SE TOYOTA CLEAN TITLE!!!
#
#       Make  Model  Year   condition     cylinders drive     fuel odometer  \
# 0   Toyota  Camry  2017   like new    4 cylinders   fwd   gas      11411
# 1   Toyota  Camry  2015   like new    4 cylinders   fwd   hybrid   13500
# 2   Toyota  Camry  2014   excellent  NaN           NaN    gas      44800
# 3   Toyota  Camry  2014   excellent  NaN           NaN    gas      44800
# 4   Toyota  Camry  2012   like new    4 cylinders   fwd   gas      77615
# 5   Toyota  Camry  2008   like new    4 cylinders   fwd   gas      100000
# 6   Toyota  Camry  2008   excellent   6 cylinders  NaN    gas      86000
# 7   Toyota  Camry  2009   good        4 cylinders   fwd   gas      107700
# 8   Toyota  Camry  2008   excellent   4 cylinders   fwd   gas      139000
# 9   Toyota  Camry  2009   good        4 cylinders   fwd   gas      122789
# 10  Toyota  Camry  2011   excellent   4 cylinders  NaN    gas      153100
# 11  Toyota  Camry  2011   excellent   4 cylinders  NaN    gas      64000
# 12  Toyota  Camry  2015   like new    4 cylinders   fwd   gas      88000
# 13  Toyota  Camry  2014   excellent   4 cylinders   fwd   gas      70300
# 14  Toyota  Camry  2018   like new    4 cylinders  NaN    gas      15502
# 15  Toyota  Camry  2014   good        6 cylinders  NaN    gas      68000
# 16  Toyota  Camry  2013   excellent   4 cylinders   rwd   gas      140000
# 17  Toyota  Camry  2008   excellent   4 cylinders   fwd   hybrid   153000
# 18  Toyota  Camry  2011   excellent   4 cylinders   fwd   gas      71000
# 19  Toyota  Camry  2012   excellent  NaN           NaN    gas      90000
# 20  Toyota  Camry  2016   like new    4 cylinders   fwd   gas      35500
# 21  Toyota  Camry  2014   like new   NaN           NaN    gas      46000
# 22  Toyota  Camry  2012   like new    4 cylinders  NaN    gas      58000
# 23  Toyota  Camry  2013   good        4 cylinders   fwd   gas      63249
# 24  Toyota  Camry  2011   excellent   4 cylinders  NaN    gas      69000
# 25  Toyota  Camry  2014   excellent   4 cylinders  NaN    gas      29000
# 26  Toyota  Camry  2014   excellent   4 cylinders  NaN    gas      29000
# 27  Toyota  Camry  2014   excellent   4 cylinders  NaN    gas      29000
# 28  Toyota  Camry  2010   excellent   4 cylinders   fwd   gas      97000
# 29  Toyota  Camry  2008   excellent   4 cylinders   fwd   gas      138243
# 30  Toyota  Camry  2009   excellent   4 cylinders   rwd   gas      168000
# 31  Toyota  Camry  2018   like new    4 cylinders  NaN    gas      15520
# 32  Toyota  Camry  2017   like new   NaN           NaN    gas      14000
# 33  Toyota  Camry  2008   good        4 cylinders   fwd   hybrid   153000
# 34  Toyota  Camry  2014   good        4 cylinders   fwd   gas      61007
# 35  Toyota  Camry  2009   like new    4 cylinders   fwd   gas      98000
# 36  Toyota  Camry  2009   like new    4 cylinders   fwd   gas      98000
# 37  Toyota  Camry  2016   good        4 cylinders  NaN    gas      59000
# 38  Toyota  Camry  2017   new         4 cylinders   fwd   gas      20785
# 39  Toyota  Camry  2014   excellent   4 cylinders   fwd   gas      44000
# 40  Toyota  Camry  2009   excellent   4 cylinders   fwd   gas      29400
# 41  Toyota  Camry  2009   excellent   4 cylinders   fwd   gas      146000
# 42  Toyota  Camry  2009   good        4 cylinders  NaN    gas      153
# 43  Toyota  Camry  2014   excellent   4 cylinders   fwd   gas      44000
# 44  Toyota  Camry  2012   excellent  NaN           NaN    gas      72600
# 45  Toyota  Camry  2009   excellent   6 cylinders   fwd   gas      128000
# 46  Toyota  Camry  2011   excellent   4 cylinders   fwd   gas      128000
# 47  Toyota  Camry  2010   excellent   4 cylinders  NaN    gas      91000
# 48  Toyota  Camry  2015   excellent   4 cylinders  NaN    gas      70987
# 49  Toyota  Camry  2014   excellent   4 cylinders   fwd   gas      102000
#
#    paint color          size title status transmission    type   Price  \
# 0    grey        mid-size      salvage      automatic    sedan  $13795
# 1    blue        mid-size      clean        automatic    sedan  $22000
# 2   NaN         NaN            clean        automatic   NaN     $13500
# 3   NaN         NaN            clean        automatic   NaN     $13500
# 4    silver      compact       clean        automatic    sedan  $10500
# 5    black       compact       clean        automatic    sedan  $5700
# 6   NaN         NaN            clean        automatic   NaN     $7950
# 7    black       full-size     salvage      automatic    sedan  $4650
# 8    red         mid-size      clean        automatic    sedan  $5500
# 9    black       compact       salvage      automatic    sedan  $4500
# 10   brown      NaN            clean        automatic   NaN     $5500
# 11  NaN         NaN            clean        automatic   NaN     $10300
# 12   black       mid-size      clean        automatic    sedan  $12900
# 13   grey       NaN            clean        automatic   NaN     $13600
# 14   blue        full-size     clean        automatic   NaN     $20000
# 15  NaN         NaN            clean        automatic   NaN     $13500
# 16   black       full-size     clean        automatic    sedan  $8300
# 17   brown       full-size     clean        automatic    sedan  $5550
# 18   grey        mid-size      salvage      automatic   NaN     $6800
# 19  NaN         NaN            salvage      automatic   NaN     $7200
# 20   blue        full-size     clean        automatic    sedan  $15999
# 21   black      NaN            clean        automatic   NaN     $11500
# 22  NaN         NaN            clean        automatic   NaN     $11800
# 23   grey        mid-size      clean        automatic    sedan  $12600
# 24   silver     NaN            salvage      automatic   NaN     $8500
# 25  NaN         NaN            clean        automatic    sedan  $14500
# 26  NaN         NaN            clean        automatic    sedan  $14500
# 27  NaN         NaN            clean        automatic    sedan  $14500
# 28   silver      compact       clean        automatic    sedan  $6800
# 29   silver      full-size     clean        automatic    sedan  $6400
# 30  NaN         NaN            clean        automatic    sedan  $4799
# 31  NaN         NaN            clean        automatic    sedan  $20900
# 32  NaN         NaN            clean        automatic   NaN     $17000
# 33   brown       full-size     clean        automatic    sedan  $5500
# 34   grey       NaN            clean        automatic    sedan  $11900
# 35   blue        full-size     clean        automatic    sedan  $6300
# 36   blue        full-size     clean        automatic    sedan  $5999
# 37  NaN         NaN            clean        automatic   NaN     $16500
# 38   black       full-size     clean        automatic    sedan  $16450
# 39   black       full-size     salvage      automatic    sedan  $8900
# 40   silver      sub-compact   salvage      automatic    sedan  $7299
# 41   white       mid-size      clean        automatic    sedan  $6600
# 42   silver      compact       clean        automatic    sedan  $5500
# 43   black       full-size     salvage      automatic    sedan  $8900
# 44  NaN         NaN            clean        automatic    sedan  $9500
# 45   grey        compact       clean        automatic    sedan  $6500
# 46   grey       NaN            clean        automatic    sedan  $7500
# 47   silver      compact       clean        automatic    sedan  $8000
# 48   silver     NaN            clean        automatic   NaN     $12500
# 49   grey        mid-size      clean        automatic    sedan  $11000
#
#                    VIN  \
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN