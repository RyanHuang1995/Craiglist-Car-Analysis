# %%
 # Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd

# %%
csv_file_path = ("../Car price data/prius_data.csv")

# %%
# Using Splinter Scraping data
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
# URL of page to be scraped
url = 'https://losangeles.craigslist.org/search/cto?min_price=2000&auto_make_model=prius&min_auto_year=2008&max_auto_year=2018&min_auto_miles=0&max_auto_miles=1000000&condition=10&condition=20&condition=30&condition=40'

# %%
# Scrape the data based on post info
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html,"html.parser")
next_page = soup.find("a",class_ = "button next")["href"]

titles = []
prices = []
links = []
car_data = []

while next_page:
    print(" - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - - ")
    html = browser.html
    soup = BeautifulSoup(html,"html.parser")
    results = soup.find_all('li', class_="result-row")
    
    
    
    
    for result in results:
    # Error handling
        try:
            # Identify and return title of listing
            title = result.find('a', class_="result-title").text
            # Identify and return price of listing
            price = result.a.span.text
            # Identify and return link to listing
            link = result.a['href']

            # Print results only if title, price, and link are available
            if (title and price and link):
                titles.append(title)
                prices.append(price)
                links.append(link)
                
                post_link = result.a["href"]
                response2 = requests.get(post_link)
                soup2 = BeautifulSoup(response2.text,"html.parser")
                attributes = soup2.find_all("p",class_="attrgroup")
                attribute_list = attributes[1].find_all("span")
                attr_dic = {}
                
                try:
                
                    tag = attributes[0].find("span").find("b").text.split(" ")
                
                    yearlist = [str(num) for num in list(range(1900, 2020))]
                    for word in tag:
                        if word in yearlist:
                            year = word
                            for attr in attribute_list:
                                try:
                                    key,value = attr.text.split(":")
                                    attr_dic[key] = value
                                    attr_dic["Year"] = year
                                except ValueError:
                                    pass
                            if word not in tag:
                                attr_dic["Year"] = "NA"
                    
                    
                except:
                    attr_dic["Year"] = "NA"
                
    
                car_data.append(attr_dic)
                
                
        except AttributeError as e:
            print(e)
    try:
        browser.click_link_by_partial_text('next')
        next_page = soup.find("a",class_ = "button next")["href"]
    except:
        print("- - - - - - - - - This is the last page we can find!!!- - - - - -")
        next_page = False
# Out:
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# - - - - - - - - - This is the last page we can find!!!- - - - - -

# %%
# Store info as dataframe
info_df = pd.DataFrame({
    "Info" : titles,
    "Price" : prices,
    "links" : links
})

# %%
# Show full dataframe
pd.set_option('display.max_colwidth', -1)
# Merge two dataframe
car_df = pd.DataFrame(car_data)
car_df["Title"] = info_df["Info"]
car_df["Price"] = info_df["Price"]
car_df["Link"] = info_df["links"]
car_df["Make"] = "Toyota"
car_df["Model"] = "Prius"
car_df = car_df[['Title','Make', 'Model','Year', 'condition', 'cylinders', 'drive', 'fuel', 'odometer',
       'paint color', 'size', 'title status', 'transmission', 'type', 
       'Price', 'VIN', 'Link']]
car_df.head(50)
# Out:
#                                                                      Title  \
# 0   2009 Toyota Pirus IV, 112000 miles
# 1   2009 Toyota Prius clean title clean carfax camera 178k
# 2   2008 TOYOTA PRIUS -- 81,000 MILES -
# 3   ** 2011 Toyota Prius **
# 47  Toyota  Prius  2011   excellent   4 cylinders   fwd   hybrid   68700
# 48  Toyota  Prius  2010   like new    4 cylinders   fwd   hybrid   60380
# 49  Toyota  Prius  2011   good        4 cylinders   fwd   hybrid   259400
#
#    paint color        size title status transmission        type   Price  \
# 0    white       compact     clean        automatic    sedan      $7800
# 1   NaN          compact     clean        automatic    hatchback  $4400
# 2    green       compact     clean        automatic    hatchback  $10500
# 3    white       mid-size    clean        automatic    hatchback  $9900
# 4   NaN         NaN          clean        automatic   NaN         $7400
# 5   NaN         NaN          clean        automatic   NaN         $12900
# 6    black       compact     clean        automatic    hatchback  $22500
# 7    white       full-size   clean        automatic    sedan      $20900
# 8   NaN         NaN          clean        automatic    hatchback  $3995
# 9    white       full-size   clean        automatic    hatchback  $5800
# 10   white      NaN          salvage      automatic   NaN         $16500
# 11  NaN         NaN          clean        automatic   NaN         $15500
# 12   white      NaN          salvage      automatic   NaN         $9500
# 13   black      NaN          salvage      automatic   NaN         $8200
# 14   white       mid-size    clean        automatic    sedan      $13900
# 15   white       compact     clean        automatic    hatchback  $15000
# 16   black       compact     salvage      automatic    hatchback  $9500
# 17   grey        compact     clean        automatic    hatchback  $13990
# 18  NaN         NaN          clean        automatic   NaN         $5950
# 19   blue        compact     clean        automatic    hatchback  $5900
# 20  NaN         NaN          clean        automatic   NaN         $5950
# 21   grey       NaN          clean        automatic   NaN         $12500
# 22  NaN          mid-size    salvage      automatic    sedan      $5700
# 23   black      NaN          clean        automatic    hatchback  $5950
# 24   black       compact     clean        automatic    hatchback  $6500
# 25  NaN         NaN          salvage      automatic   NaN         $4200
# 26   white       full-size   clean        automatic    hatchback  $10500
# 27   blue        compact     clean        automatic    hatchback  $13500
# 28   blue        full-size   clean        automatic    hatchback  $12800
# 29   blue        compact     clean        automatic    hatchback  $5900
# 30   blue        compact     clean        automatic    hatchback  $9500
# 31   blue        compact     clean        automatic    hatchback  $14900
# 32   black       compact     salvage      automatic    hatchback  $5700
# 33   white       compact     clean        automatic    hatchback  $15000
# 34   grey       NaN          salvage      automatic   NaN         $5000
# 35   white       full-size   clean        automatic   NaN         $13500
# 36   white       full-size   clean        automatic   NaN         $13500
# 37   white       full-size   clean        automatic   NaN         $13500
# 38   white       full-size   clean        automatic   NaN         $13500
# 39   silver     NaN          salvage      automatic    sedan      $4300
# 40   silver      mid-size    clean        automatic    hatchback  $11500
# 41   white       full-size   clean        automatic   NaN         $13500
# 42   black      NaN          salvage      automatic   NaN         $5000
# 43   white       full-size   clean        automatic    sedan      $13500
# 44   white       full-size   clean        automatic    sedan      $13500
# 45  NaN         NaN          salvage      automatic   NaN         $5000
# 46   white       full-size   clean        automatic    sedan      $13500
# 47   grey        compact     salvage      automatic    hatchback  $7300
# 48   brown       compact     salvage      automatic    hatchback  $7499
# 49   green       compact     clean        automatic    hatchback  $4100
#
#                    VIN  \
# 0    JTDKB20U797858488
# 1   NaN
