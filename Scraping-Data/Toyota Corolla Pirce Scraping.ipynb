# %%
 # Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd

# %%
csv_file_path = ("../Car price data/corolla_data.csv")

# %%
# Using Splinter Scraping data
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
# URL of page to be scraped
url = 'https://losangeles.craigslist.org/search/cto?min_price=2000&auto_make_model=corolla&min_auto_year=2008&max_auto_year=2018&min_auto_miles=0&max_auto_miles=1000000&condition=10&condition=20&condition=30&condition=40'

# %%
# Scrape the data based on post info
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html,"html.parser")
next_page = soup.find("a",class_ = "button next")["href"]

titles = []
prices = []
links = []
car_data = []

while next_page:
    print(" - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - - ")
    html = browser.html
    soup = BeautifulSoup(html,"html.parser")
    results = soup.find_all('li', class_="result-row")
    
    
    
    
    for result in results:
    # Error handling
        try:
            # Identify and return title of listing
            title = result.find('a', class_="result-title").text
            # Identify and return price of listing
            price = result.a.span.text
            # Identify and return link to listing
            link = result.a['href']

            # Print results only if title, price, and link are available
            if (title and price and link):
                titles.append(title)
                prices.append(price)
                links.append(link)
                
                post_link = result.a["href"]
                response2 = requests.get(post_link)
                soup2 = BeautifulSoup(response2.text,"html.parser")
                attributes = soup2.find_all("p",class_="attrgroup")
                attribute_list = attributes[1].find_all("span")
                attr_dic = {}
                
                try:
                
                    tag = attributes[0].find("span").find("b").text.split(" ")
                
                    yearlist = [str(num) for num in list(range(1900, 2020))]
                    for word in tag:
                        if word in yearlist:
                            year = word
                            for attr in attribute_list:
                                try:
                                    key,value = attr.text.split(":")
                                    attr_dic[key] = value
                                    attr_dic["Year"] = year
                                except ValueError:
                                    pass
                            if word not in tag:
                                attr_dic["Year"] = "NA"
                    
                    
                except:
                    attr_dic["Year"] = "NA"
                
    
                car_data.append(attr_dic)
                
                
        except AttributeError as e:
            print(e)
    try:
        browser.click_link_by_partial_text('next')
        next_page = soup.find("a",class_ = "button next")["href"]
    except:
        print("- - - - - - - - - This is the last page we can find!!!- - - - - -")
        next_page = False
# Out:
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
#  - - - - - - - - - - - Scraping New Page Starts!! - - - - - - - - -
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# - - - - - - - - - This is the last page we can find!!!- - - - - -

# %%
# Store info as dataframe
info_df = pd.DataFrame({
    "Info" : titles,
    "Price" : prices,
    "links" : links
})

# %%
# Show full dataframe
pd.set_option('display.max_colwidth', -1)
# Merge two dataframe
car_df = pd.DataFrame(car_data)
car_df["Title"] = info_df["Info"]
car_df["Price"] = info_df["Price"]
car_df["Link"] = info_df["links"]
car_df["Make"] = "Toyota"
car_df["Model"] = "Corolla"
car_df = car_df[['Title','Make', 'Model','Year', 'condition', 'cylinders', 'drive', 'fuel', 'odometer',
       'paint color', 'size', 'title status', 'transmission', 'type', 
       'Price', 'VIN', 'Link']]
car_df.head(50)
# Out:
#                                                                     Title  \
# 0   2009 Toyota Corolla LE excellent condition
# 1   2017 toyota Corolla
# 2   2008 Toyota Corolla LE - Automatic - Clean Title - 128k Miles
# 3   2008 TOYOTA COROLLA S
# 4   2012 toyota corolla
# 5   Toyota Corolla S 2014 (Manual)
# 6   2017 Toyota Corolla Le 2,400 miles
# 7   2015 TOYOTA COROLLA
# 8   2012 toyota corolla
# 9   2010 TOYOTA COROLLA  LE NICE CAR EXCELLENT CONDITION GOOD DEAL
# 10  2010 Toyota Corolla
# 11  2015 TOYOTA COROLLA
# 12  Toyota Corolla
# 13  2014 Toyota Corolla   Sport
# 14  2014 Toyota Corolla LE
# 15  2013 Toyota Corolla LE, 46k miles 1 owner, like new, only next 4 days
# 16  2010 Toyota Corolla S sedan súper clean
# 17  2008 Toyota Corolla CE
# 18  2009 Toyota Corolla S
# 19  2012 Toyota Corolla LE 4 Cylinders
# 20  2010 Toyota Corolla LE- $7700
# 21  2016 Toyota Corolla S 2017
# 22  2017 Toyota Corolla L - 4D Sedan ** One Owner - Clean Title **
# 23  2012 toyota corolla
# 24  2012 TOYOTA COROLLA S 56k miles $6300$
# 25  2014 Toyota Corolla
# 26  2012 toyota corolla
# 27  2012 toyota corolla
# 28  2012 toyota corolla
# 29  2010 Toyota Corolla LE
# 30  2012 Toyota Corolla LE 4 Cylinders
# 31  2012 toyota corolla
# 32  2013 TOYOTA  COROLLA  LE.
# 33  2014 TOYOTA  COROLLA  LE
# 34  2013 Toyota Corolla LE
# 35  2012 toyota corolla
# 36  2010 Toyota Corolla S loaded one owner runs great gas saver
# 37  2012 toyota corolla
# 38  2010 Toyota Corolla LE in excellent condition!
# 39  2012 Toyota Corolla LE 4 Cylinders
# 40  2012 toyota corolla
# 41  2015 Toyota COROLLA L *50K Miles* 1.8L I4  No Accident / Damage
# 42  2012 toyota corolla
# 43  2017 Toyota Corolla L  Sedan ** Clean Title - One Owner **
# 44  2012 Toyota Corolla LE 4 Cylinders
# 45  2010 Toyota Corolla LE- $7700
# 46  2015 Toyota COROLLA L *Low 35,053 Miles*
# 47  2012 toyota corolla
# 48  2009 Toyota Corolla
# 49  2013 TOYOTA COROLLA SPORT
#
#       Make    Model  Year   condition     cylinders drive  fuel odometer  \
# 0   Toyota  Corolla  2009   excellent   4 cylinders   fwd   gas   134000
# 1   Toyota  Corolla  2017   like new    4 cylinders   fwd   gas   22000
# 2   Toyota  Corolla  2008   excellent   4 cylinders   fwd   gas   128000
# 3   Toyota  Corolla  2008   excellent   4 cylinders  NaN    gas   112000
# 4   Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   128000
# 5   Toyota  Corolla  2014   new         4 cylinders   fwd   gas   37000
# 6   Toyota  Corolla  2017   like new    4 cylinders   fwd   gas   2400
# 7   Toyota  Corolla  2015   like new    4 cylinders   fwd   gas   65000
# 8   Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   128000
# 9   Toyota  Corolla  2010   excellent   4 cylinders   fwd   gas   119157
# 10  Toyota  Corolla  2010   good        4 cylinders   fwd   gas   107000
# 11  Toyota  Corolla  2015   like new    4 cylinders   fwd   gas   65000
# 12  Toyota  Corolla  2010   excellent   4 cylinders  NaN    gas   104000
# 13  Toyota  Corolla  2014   good        4 cylinders  NaN    gas   92
# 14  Toyota  Corolla  2014   excellent   4 cylinders   fwd   gas   107600
# 15  Toyota  Corolla  2013   like new    4 cylinders   fwd   gas   46000
# 16  Toyota  Corolla  2010   excellent   4 cylinders   fwd   gas   131360
# 17  Toyota  Corolla  2008   good        4 cylinders   fwd   gas   117500
# 18  Toyota  Corolla  2009   good        4 cylinders   fwd   gas   187310
# 19  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   129000
# 20  Toyota  Corolla  2010   like new    4 cylinders   fwd   gas   115800
# 21  Toyota  Corolla  2016   excellent   4 cylinders   fwd   gas   50000
# 22  Toyota  Corolla  2017   excellent   4 cylinders   fwd   gas   44800
# 23  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   128000
# 24  Toyota  Corolla  2012   good        4 cylinders   fwd   gas   55800
# 25  Toyota  Corolla  2014   like new   NaN           NaN    gas   61000
# 26  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   128000
# 27  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   128000
# 28  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   128000
# 29  Toyota  Corolla  2010   excellent   4 cylinders   fwd   gas   109206
# 30  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   129000
# 31  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   128000
# 32  Toyota  Corolla  2013   excellent   4 cylinders   fwd   gas   25801
# 33  Toyota  Corolla  2014   excellent   4 cylinders   fwd   gas   35801
# 34  Toyota  Corolla  2013   like new    4 cylinders   fwd   gas   121000
# 35  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   128000
# 36  Toyota  Corolla  2010   like new    4 cylinders   fwd   gas   131300
# 37  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   128000
# 38  Toyota  Corolla  2010   excellent   4 cylinders   fwd   gas   131336
# 39  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   129000
# 40  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   128000
# 41  Toyota  Corolla  2015   good        4 cylinders   fwd   gas   49156
# 42  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   128000
# 43  Toyota  Corolla  2017   excellent   4 cylinders   fwd   gas   44800
# 44  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   129000
# 45  Toyota  Corolla  2010   like new    4 cylinders   fwd   gas   115800
# 46  Toyota  Corolla  2015   excellent   4 cylinders   fwd   gas   35053
# 47  Toyota  Corolla  2012   excellent   4 cylinders  NaN    gas   128
# 48  Toyota  Corolla  2009   excellent   4 cylinders   fwd   gas   113500
# 49  Toyota  Corolla  2013   excellent  NaN           NaN    gas   144000
#
#    paint color        size title status transmission    type   Price  \
# 0    black       full-size   clean        automatic    sedan  $6300
# 1    blue        compact     clean        automatic    sedan  $13800
# 2    silver     NaN          clean        automatic    sedan  $4950
# 3   NaN         NaN          clean        automatic   NaN     $5550
# 4   NaN         NaN          clean        automatic   NaN     $6800
# 5    white      NaN          clean        manual       sedan  $11900
# 6    white       compact     clean        automatic    sedan  $16995
# 7    blue        compact     salvage      automatic    sedan  $7800
# 8   NaN         NaN          clean        automatic   NaN     $6800
# 9    white       mid-size    clean        automatic    sedan  $5980
# 10   white       compact     salvage      automatic    sedan  $5500
# 11   blue        compact     salvage      automatic    sedan  $7800
# 12   white      NaN          clean        automatic    sedan  $6500
# 13  NaN         NaN          clean        automatic   NaN     $9300
# 14   white       compact     clean        automatic    sedan  $9200
# 15   silver     NaN          clean        automatic   NaN     $9800
# 16   black       full-size   clean        automatic    sedan  $6950
# 17   white       compact     clean        automatic    sedan  $4999
# 18   silver      compact     clean        automatic    sedan  $6500
# 19  NaN         NaN          clean        automatic   NaN     $6800
# 20   white       mid-size    clean        automatic    sedan  $7700
# 21   blue        compact     salvage      automatic    sedan  $10800
# 22   grey        compact     clean        automatic    sedan  $13750
# 23  NaN         NaN          clean        automatic   NaN     $6800
# 24   black       compact     salvage      automatic    sedan  $6200
# 25   white      NaN          clean        automatic   NaN     $14000
# 26  NaN         NaN          clean        automatic   NaN     $6800
# 27  NaN         NaN          clean        automatic   NaN     $6800
# 28  NaN         NaN          clean        automatic   NaN     $6800
# 29   black       compact     clean        automatic    sedan  $7499
# 30  NaN         NaN          clean        automatic   NaN     $7000
# 31  NaN         NaN          clean        automatic   NaN     $6800
# 32   blue        compact     salvage      automatic    sedan  $6950
# 33   green       compact     salvage      automatic    sedan  $8600
# 34   white       compact     clean        automatic    sedan  $6999
# 35  NaN         NaN          clean        automatic   NaN     $6800
# 36   black       mid-size    clean        automatic    sedan  $6600
# 37  NaN         NaN          clean        automatic   NaN     $6800
# 38   silver      compact     clean        automatic    sedan  $5799
# 39  NaN         NaN          clean        automatic   NaN     $7000
# 40  NaN         NaN          clean        automatic   NaN     $6800
# 41   silver     NaN          clean        automatic    sedan  $11900
# 42  NaN         NaN          clean        automatic   NaN     $6800
# 43   grey        compact     clean        automatic    sedan  $13750
# 44  NaN         NaN          clean        automatic   NaN     $7000
# 45   white       mid-size    clean        automatic    sedan  $7700
# 46   silver     NaN          clean        automatic    sedan  $11900
# 47  NaN         NaN          clean        automatic   NaN     $6800
# 48   blue        compact     clean        automatic    sedan  $5600
# 49   black      NaN          clean        automatic   NaN     $7500
#
#                    VIN  \
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12   1NXBU4EE3AZ262285
# 13  NaN
# 14   5YFBURHE3EP002971
# 15   5YFBU4EEXDP214711
# 16  NaN
# 17  NaN
# 18   1NXBU40E19Z148949
# 19  NaN
# 20  NaN
# 21   5YFBURHEXGP458579
# 22   5YFBURHE6HP627501
# 23  NaN
# 24  NaN
# 25   Clean title
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
# 30  NaN
# 31  NaN
# 32  NaN
# 33  NaN
# 34   2T1BU4EE4DC016464
# 35  NaN
# 36  NaN
# 37  NaN
# 38   2t1bu4ee8ac516736
# 39  NaN
# 40  NaN
# 41   5YFBURHE6FP311013
# 42  NaN
# 43   5YFBURHE6HP627501
# 44  NaN
# 45  NaN
# 46   5YFBURHE9FP312950
# 47  NaN
# 48  NaN
# 49  NaN
#
#                                                                                          Link
# 0   https://losangeles.craigslist.org/sgv/cto/d/2009-toyota-corolla-le/6706505472.html
# 1   https://losangeles.craigslist.org/lac/cto/d/2017-toyota-corolla/6704636484.html
# 2   https://losangeles.craigslist.org/sfv/cto/d/2008-toyota-corolla-le/6710546688.html
# 3   https://losangeles.craigslist.org/lac/cto/d/2008-toyota-corolla/6710498444.html
# 4   https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla/6710326989.html
# 5   https://losangeles.craigslist.org/lac/cto/d/toyota-corolla-2014-manual/6710322232.html
# 6   https://losangeles.craigslist.org/sgv/cto/d/2017-toyota-corolla-le-2400/6708560060.html
# 7   https://losangeles.craigslist.org/lac/cto/d/2015-toyota-corolla/6707420641.html
# 8   https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla/6710251342.html
# 9   https://losangeles.craigslist.org/lac/cto/d/2010-toyota-corolla-le-nice/6692209163.html
# 10  https://losangeles.craigslist.org/sfv/cto/d/2010-toyota-corolla/6695558330.html
# 11  https://losangeles.craigslist.org/lac/cto/d/2015-toyota-corolla/6710220303.html
# 12  https://losangeles.craigslist.org/lgb/cto/d/toyota-corolla/6693144822.html
# 13  https://losangeles.craigslist.org/lac/cto/d/2014-toyota-corolla-sport/6696911242.html
# 14  https://losangeles.craigslist.org/sfv/cto/d/2014-toyota-corolla-le/6694243548.html
# 15  https://losangeles.craigslist.org/sgv/cto/d/2013-toyota-corolla-le-46k/6710014378.html
# 16  https://losangeles.craigslist.org/sgv/cto/d/2010-toyota-corolla-sedan/6709987427.html
# 17  https://losangeles.craigslist.org/sfv/cto/d/2008-toyota-corolla-ce/6709937604.html
# 18  https://losangeles.craigslist.org/sgv/cto/d/2009-toyota-corolla/6709915166.html
# 19  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla-le-4/6707704651.html
# 20  https://losangeles.craigslist.org/wst/cto/d/2010-toyota-corolla-le-7700/6709768318.html
# 21  https://losangeles.craigslist.org/sfv/cto/d/2016-toyota-corolla-2017/6709743969.html
# 22  https://losangeles.craigslist.org/lac/cto/d/2017-toyota-corolla-4d-sedan/6709749150.html
# 23  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla/6709737941.html
# 24  https://losangeles.craigslist.org/sfv/cto/d/2012-toyota-corolla-56k-miles/6684434438.html
# 25  https://losangeles.craigslist.org/lac/cto/d/2014-toyota-corolla/6709646684.html
# 26  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla/6709588852.html
# 27  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla/6709453750.html
# 28  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla/6709442920.html
# 29  https://losangeles.craigslist.org/lac/cto/d/2010-toyota-corolla-le/6709434182.html
# 30  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla-le-4/6705697717.html
# 31  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla/6709417752.html
# 32  https://losangeles.craigslist.org/lac/cto/d/2013-toyota-corolla-le/6706778794.html
# 33  https://losangeles.craigslist.org/lac/cto/d/2014-toyota-corolla-le/6706804559.html
# 34  https://losangeles.craigslist.org/lac/cto/d/2013-toyota-corolla-le/6699438536.html
# 35  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla/6709368541.html
# 36  https://losangeles.craigslist.org/lgb/cto/d/2010-toyota-corolla-loaded/6699130302.html
# 37  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla/6709310402.html
# 38  https://losangeles.craigslist.org/lac/cto/d/2010-toyota-corolla-le-in/6709266003.html
# 39  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla-le-4/6707297661.html
# 40  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla/6709203632.html
# 41  https://losangeles.craigslist.org/lac/cto/d/2015-toyota-corolla-50k-miles/6707203395.html
# 42  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla/6709097753.html
# 43  https://losangeles.craigslist.org/wst/cto/d/2017-toyota-corolla-sedan/6708978390.html
# 44  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla-le-4/6707120847.html
# 45  https://losangeles.craigslist.org/wst/cto/d/2010-toyota-corolla-le-7700/6708935571.html
# 46  https://losangeles.craigslist.org/lac/cto/d/2015-toyota-corolla-lowmiles/6703877540.html
# 47  https://losangeles.craigslist.org/lac/cto/d/2012-toyota-corolla/6708889846.html
# 48  https://losangeles.craigslist.org/sgv/cto/d/2009-toyota-corolla/6703456503.html
# 49  https://losangeles.craigslist.org/lgb/cto/d/2013-toyota-corolla-sport/6690038765.html

# %%
# Out put as CSV file
car_df.to_csv(csv_file_path)
