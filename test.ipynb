# %%
import os
from flask import Flask
from flask import jsonify
from flask import request
from flask import make_response
from flask import url_for
from flask import render_template

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import pymysql

pymysql.install_as_MySQLdb()

# %%
#create engine object based on URL
engine = create_engine("sqlite:///Car-Price-Data/Craiglist.db")

#reflect database
Base = automap_base()

#reflect the database's tables
Base.prepare(engine, reflect=True)

#create session from Python to the database
session = Session(bind=engine)

# %%
#create mapped class for database
Craiglist_Car = Base.classes.Craiglist_Car

# %%
#instantiate flask app
app = Flask(__name__)

# %%
#route to retrieve model data
@app.route("/<choice>")
def make(choice):
    
    #test
    #choice = "ACCORD"
    
    #create list 
    title = []
    make = []
    model = []
    year = []
    condition = []
    cylinders = []
    drive = []
    fuel = []
    odometer = []
    color = []
    size = []
    title_status = []
    transmission = []
    typeList = []
    price = []
    vin = []
    link = []
    
    #manipulate string to query correct rows 
    choice = choice.title()
    
    #query for data by model
    result = session.query(Craiglist_Car).filter(Craiglist_Car.model == choice).all()

    #loop through table queries and create dictionary
    for row in result:
        title.append(row.title)
        make.append(row.make)
        model.append(row.model)
        year.append(row.year)
        condition.append(row.condition)
        cylinders.append(row.cylinders)
        drive.append(row.drive)
        fuel.append(row.fuel)
        odometer.append(row.odometer)
        color.append(row.paint_color)
        size.append(row.size)
        title_status.append(row.title_status)
        transmission.append(row.transmission)
        typeList.append(row.type)
        price.append(row.price)
        vin.append(row.VIN)
        link.append(row.link)
    
        AccordDict = {"PostTitle": title, "Make": make, "Model": model, "Year": year, "Condition": condition, 
                       "Cyclinder": cylinders, "Drive": drive, "Fuel": fuel, "Odometer": odometer, "Color": color,
                       "Size": size, "TitleStatus": title_status, "Transmission": transmission, "Type": typeList,
                       "Price": price, "VIN": vin, "PostLink": link}

    return jsonify(AccordDict)
# Out:
#   File "<ipython-input-73-669bb3739df9>", line 6
#     make = "ACCORD"
#     ^
# IndentationError: unexpected indent

# %%
carResultList =[]
#query for data by model
result = session.query(Craiglist_Car).filter(Craiglist_Car.model == "Accord").all()

#loop through table queries and create dictionary
for row in result:
    count = 1

    
    dictionary = {"Result Number": count, "Post Title": row.title, "Make": row.make, "Model": row.model, "Year": row.year, "Condition": row.condition, 
                       "Cyclinder": row.cylinders, "Drive": row.drive, "Fuel": row.fuel, "Odometer": row.odometer, "Color": row.paint_color,
                       "Size": row.size, "Title Status": row.title_status, "Transmission": row.transmission, "Type": row.type,
                       "Price": row.price, "VIN": row.VIN, "Post Link": row.link}
        
    count+=1

    carResultList.append(dictionary)

print(carResultList)
# Out:
# [{'Result Number': 1, 'Post Title': 'Honda Accord', 'Make': 'Honda', 'Model': 'Accord', 'Year': 2010, 'Condition': ' good', 'Cyclinder': ' 4 cylinders', 'Drive': ' fwd', 'Fuel': ' gas', 'Odometer': 117000, 'Color': ' grey', 'Size': ' mid-size', 'Title Status': ' salvage', 'Transmission': ' automatic', 'Type': ' sedan', 'Price': '$5800', 'VIN': ' 1hgcp2f34aa019623', 'Post Link': 'https://losangeles.craigslist.org/lgb/cto/d/honda-accord/6710644067.html'}, {'Result Number': 1, 'Post Title': '2012 Honda accord coupe', 'Make': 'Honda', 'Model': 'Accord', 'Year': 2012, 'Condition': ' excellent', 'Cyclinder': ' 4 cylinders', 'Drive': None, 'Fuel': ' gas', 'Odometer': 111, 'Color': None, 'Size': None, 'Title Status': ' clean', 'Transmission': ' automatic', 'Type': None, 'Price': '$7995', 'VIN': None, 'Post Link': 'https://losangeles.craigslist.org/wst/cto/d/2012-honda-accord-coupe/6699535701.html'}, {'Result Number': 1, 'Post Title': '2017 Honda Acoord Sport', 'Make': 'Honda', 'Model': 'Accord', 'Year': 2017, 'Condition': ' good', 'Cyclinder': ' 4 cylinders', 'Drive': ' fwd', 'Fuel': ' gas', 'Odometer': 22, 'Color': ' black', 'Size': ' mid-size', 'Title Status': ' salvage', 'Transmission': ' automatic', 'Type': ' sedan', 'Price': '$14500', 'VIN': None, 'Post Link': 'https://losangeles.craigslist.org/lgb/cto/d/2017-honda-acoord-sport/6703846822.html'}, {'Result Number': 1, 'Post Title': '2017 Honda Accord sport special edition clean tittle', 'Make': 'Honda', 'Model': 'Accord', 'Year': 2017, 'Condition': ' like new', 'Cyclinder': ' 4 cylinders', 'Drive': ' fwd', 'Fuel': ' gas', 'Odometer': 2017, 'Color': ' black', 'Size': None, 'Title Status': ' clean', 'Transmission': ' automatic', 'Type': ' sedan', 'Price': '$18900', 'VIN': None, 'Post Link': 'https://losangeles.craigslist.org/wst/cto/d/2017-honda-accord-sport/6710581560.html'}, {'Result Number': 1, 'Post Title': '2011 Honda Accord Exl', 'Make': 'Honda', 'Model': 'Accord', 'Year': 2011, 'Condition': ' good', 'Cyclinder': ' 4 cylinders', 'Drive': ' fwd', 'Fuel': ' gas', 'Odometer': 82500, 'Color': ' black', 'Size': ' mid-size', 'Title Status': ' clean', 'Transmission': ' automatic', 'Type': ' sedan', 'Price': '$8300', 'VIN': ' 1HGCP2F88BA080938', 'Post Link': 'https://losangeles.craigslist.org/sfv/cto/d/2011-honda-accord-exl/6710548793.html'}, {'Result Number': 1, 'Post Title': '* 2009 Honda Accord LX-p 4Door Sedan 100K * NO ACCIDENT ,PERFE RUN !!!', 'Make': 'Honda', 'Model': 'Accord', 'Year': 2009, 'Condition': ' excellent', 'Cyclinder': ' 4 cylinders', 'Drive': None, 'Fuel': ' gas', 'Odometer': 100000, 'Color': None, 'Size': None, 'Title Status': ' clean', 'Transmission': ' automatic', 'Type': None, 'Price': '$6450', 'VIN': ' 1HGCP26499A197306', 'Post Link': 'https://losangeles.craigslist.org/lac/cto/d/2009-honda-accord-lx-4door/6694133929.html'}, {'Result Number': 1, 'Post Title': '2017 Honda Accord EX-L V6 Clean Title', 'Make': 'Honda', 'Model': 'Accord', 'Year': 2017, 'Condition': ' like new', 'Cyclinder': ' 6 cylinders', 'Drive': ' fwd', 'Fuel': ' gas', 'Odometer': 21000, 'Color': ' grey', 'Size': ' mid-size', 'Title Status': ' clean', 'Transmission': ' automatic', 'Type': ' sedan', 'Price': '$23900', 'VIN': None, 'Post Link': 'https://losangeles.craigslist.org/sfv/cto/d/2017-honda-accord-ex-v6-clean/6704045437.html'}, {'Result Number': 1, 'Post Title': '2012 Honda Accord EX-L - $10900', 'Make': 'Honda', 'Model': 'Accord', 'Year': 2012, 'Condition': ' excellent', 'Cyclinder': ' 4 cylinders', 'Drive': ' rwd', 'Fuel': ' gas', 'Odometer': 72000, 'Color': None, 'Size': None, 'Title Status': ' clean', 'Transmission': ' automatic', 'Type': ' sedan', 'Price': '$10900', 'VIN': None, 'Post Link': 'https://losangeles.craigslist.org/wst/cto/d/2012-honda-accord-ex-10900/6710429893.html'}, {'Result Number': 1, 'Post Title': 'Honda Accord 2015 palmdale', 'Make': 'Honda', 'Model': 'Accord', 'Year': 2015, 'Condition': ' like new', 'Cyclinder': ' 4 cylinders', 'Drive': None, 'Fuel': ' gas', 'Odom ...
