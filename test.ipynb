# %%
import os
from flask import Flask
from flask import jsonify
from flask import request
from flask import make_response
from flask import url_for
from flask import render_template

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import pymysql

pymysql.install_as_MySQLdb()

# %%
#create engine object based on URL
engine = create_engine("sqlite:///Car-Price-Data/Craiglist.db")

#reflect database
Base = automap_base()

#reflect the database's tables
Base.prepare(engine, reflect=True)

#create session from Python to the database
session = Session(bind=engine)

# %%
#create mapped class for database
Craiglist_Car = Base.classes.Craiglist_Car

# %%
#instantiate flask app
app = Flask(__name__)

# %%
#route to retrieve model data
@app.route("/<choice>")
def make(choice):
    
    #test
    #choice = "ACCORD"
    
    #create list 
    title = []
    make = []
    model = []
    year = []
    condition = []
    cylinders = []
    drive = []
    fuel = []
    odometer = []
    color = []
    size = []
    title_status = []
    transmission = []
    typeList = []
    price = []
    vin = []
    link = []
    
    #manipulate string to query correct rows 
    choice = choice.title()
    
    #query for data by model
    result = session.query(Craiglist_Car).filter(Craiglist_Car.model == choice).all()

    #loop through table queries and create dictionary
    for row in result:
        title.append(row.title)
        make.append(row.make)
        model.append(row.model)
        year.append(row.year)
        condition.append(row.condition)
        cylinders.append(row.cylinders)
        drive.append(row.drive)
        fuel.append(row.fuel)
        odometer.append(row.odometer)
        color.append(row.paint_color)
        size.append(row.size)
        title_status.append(row.title_status)
        transmission.append(row.transmission)
        typeList.append(row.type)
        price.append(row.price)
        vin.append(row.VIN)
        link.append(row.link)
    
        AccordDict = {"PostTitle": title, "Make": make, "Model": model, "Year": year, "Condition": condition, 
                       "Cyclinder": cylinders, "Drive": drive, "Fuel": fuel, "Odometer": odometer, "Color": color,
                       "Size": size, "TitleStatus": title_status, "Transmission": transmission, "Type": typeList,
                       "Price": price, "VIN": vin, "PostLink": link}

    return jsonify(AccordDict)
# Out:
#   File "<ipython-input-73-669bb3739df9>", line 6
#     make = "ACCORD"
#     ^
# IndentationError: unexpected indent

# %%
# Out:
# {'PostTitle': ['2012 Honda civic EX 4 doors 80K miles automatic moon roof runs great', '2016 Honda Civic LX', 'Honda Civic EXl Turbo Hatchback Honda Sensing 40mpg', '2013 Honda Civic SI One Owner Clean Title', '2018 Honda Civic', '2012 Honda Civic', 'Honda Civic EX 2014 americano,va llegando 81MIL MILLAS BOLSAS BUENAS!', 'Honda Civic coupe 2013 lx', '2015 Honda Civic SE Sedan 4D  ** Clean Title - One Owner **', 'HONDA CIVIC 2008', '2012 Honda Civic', '2008 Honda Civic', 'Honda Civic EX 2014 americano,va llegando 81MIL MILLAS BOLSAS BUENAS!', '2008 Honda Civic Hybrid', 'Stunning 2012 Honda Civic EX', '2008 Honda Civic', '2012 Honda Civic LX Coupe', 'Honda Civic Si 2D coupe 2017', '2012 Honda Civic', '2008 Honda Civic LX 120k Tituló limpio', '2010 Honda Civic LX', '12 HONDA CIVIC EXL AZUL', '2012 HONDA CIVIC HYBRID 4DR SEDAN 48MPG 40K MILES, SALVAG', '***2012 HONDA CIVIC EX-L ORIGINAL OWNER LOW MILES CLEAN TITLE***', '2012 BMW 128i convertible clean title low miles', '2013 honda civic **', '2008 Honda Civic Excellent Condition', '2008 Honda Civic Excellent Condition', '2015 Honda Civic 22k miles BY OWNER', '2017 HONDA CIVIC LX  CLEAN TITLE', '2017 Honda Civic', '2015 Honda Civic', '2013 Honda Civic LX', '>>